# %% [markdown]
# # Load Data

# %%
import pandas as pd
import platform
import numpy as np
from itertools import product
import matplotlib.pyplot as plt
from datetime import timedelta
from collections import defaultdict
import joblib
import json
import warnings
import time
from scipy.stats.mstats import winsorize
import numba
import pandas_ta as pta

import sys
import os

# Add one directory up to sys.path
sys.path.append(os.path.abspath(".."))

# Internal Libraries
from data_loader import load_and_resample_data, apply_feature_engineering
from backtest import evaluate_regression
from labeling_utils import label_and_save
from helpers import check_overfit, generate_oof_predictions, is_same_session
#

# Tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Dropout, GlobalAveragePooling1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.preprocessing import StandardScaler, RobustScaler
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.losses import Huber, MeanSquaredError
import tensorflow as tf
#

# Scikit-learn
from sklearn.base import clone, BaseEstimator, RegressorMixin, ClassifierMixin
from sklearn.model_selection import TimeSeriesSplit, cross_val_score, cross_val_predict
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression, RidgeClassifier, ElasticNet, Ridge
from sklearn.metrics import classification_report, root_mean_squared_error, mean_squared_error, mean_absolute_error, r2_score, \
    confusion_matrix, precision_recall_curve, roc_curve, auc, accuracy_score, classification_report, f1_score, precision_score, ConfusionMatrixDisplay
from sklearn.preprocessing import label_binarize, StandardScaler, LabelEncoder
from sklearn.inspection import permutation_importance
from sklearn.pipeline import make_pipeline
from sklearn.utils.class_weight import compute_sample_weight, compute_class_weight

# Models and Training
from catboost import CatBoostRegressor, CatBoostClassifier
import lightgbm as lgb
import xgboost as xgb
import optuna
import seaborn as sns
import shap
from sklearn.svm import SVC
#

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", message=".*There are no meaningful features.*", category=UserWarning)
optuna.logging.set_verbosity(optuna.logging.INFO)

market = "BTC"
LOOK_AHEAD = 12

# %% [markdown]
# # Initialize features or indicators

# %%
# This is your Cell 5: Feature Engineering Function Definitions

# --- Helper Functions for Custom Features (Some will be kept, some modified/called differently) ---
# These helpers now expect columns to be named as pandas_ta typically names them (e.g., RSI_14, EMA_10, MACD_12_26_9, etc.)

def add_price_vs_ma(df, price_col='close', ma_col_name='EMA_20', new_col_name_suffix='_vs_EMA20'):
    # Ensure ma_col_name exists (it would have been created by pandas_ta)
    if ma_col_name in df.columns and price_col in df.columns:
        # Ensure inputs are numeric before division
        df[price_col + new_col_name_suffix] = pd.to_numeric(df[price_col], errors='coerce') / pd.to_numeric(df[ma_col_name], errors='coerce')
    return df

def add_ma_vs_ma(df, ma1_col_name='EMA_10', ma2_col_name='EMA_20', new_col_name_suffix='_vs_EMA20'):
    if ma1_col_name in df.columns and ma2_col_name in df.columns:
        df[ma1_col_name + new_col_name_suffix] = pd.to_numeric(df[ma1_col_name], errors='coerce') / pd.to_numeric(df[ma2_col_name], errors='coerce')
    return df

def add_ma_slope(df, ma_col_name='EMA_10', new_col_name_suffix='_Slope_10', periods=1):
    if ma_col_name in df.columns:
        df[new_col_name_suffix] = pd.to_numeric(df[ma_col_name], errors='coerce').diff(periods) / periods
    return df

def add_rsi_signals(df, rsi_col_name='RSI_14', ob_level=70, os_level=30):
    if rsi_col_name in df.columns:
        rsi_series = pd.to_numeric(df[rsi_col_name], errors='coerce')
        df[rsi_col_name + f'_Is_Overbought_{ob_level}'] = (rsi_series > ob_level).astype(int)
        df[rsi_col_name + f'_Is_Oversold_{os_level}'] = (rsi_series < os_level).astype(int)
    return df

def add_stoch_signals(df, stoch_k_col_name='STOCHk_14_3_3', ob_level=80, os_level=20): # Default pandas_ta name for k
    if stoch_k_col_name in df.columns:
        stoch_k_series = pd.to_numeric(df[stoch_k_col_name], errors='coerce')
        df[stoch_k_col_name + f'_Is_Overbought_{ob_level}'] = (stoch_k_series > ob_level).astype(int)
        df[stoch_k_col_name + f'_Is_Oversold_{os_level}'] = (stoch_k_series < os_level).astype(int)
    return df

def add_macd_cross_signal(df, macd_col_name='MACD_12_26_9', signal_col_name='MACDs_12_26_9'): # Default pandas_ta name for signal
    if macd_col_name in df.columns and signal_col_name in df.columns:
        macd_series = pd.to_numeric(df[macd_col_name], errors='coerce')
        signal_series = pd.to_numeric(df[signal_col_name], errors='coerce')
        crossed_above = (macd_series > signal_series) & (macd_series.shift(1) < signal_series.shift(1))
        crossed_below = (macd_series < signal_series) & (macd_series.shift(1) > signal_series.shift(1))
        df[macd_col_name + '_Cross_Signal'] = np.where(crossed_above, 1, np.where(crossed_below, -1, 0))
    return df

def add_price_vs_bb(df, price_col='close', bb_upper_col='BBU_20_2.0', bb_lower_col='BBL_20_2.0'): # Default pandas_ta names
    if price_col in df.columns and bb_upper_col in df.columns and bb_lower_col in df.columns:
        price_series = pd.to_numeric(df[price_col], errors='coerce')
        bb_upper_series = pd.to_numeric(df[bb_upper_col], errors='coerce')
        bb_lower_series = pd.to_numeric(df[bb_lower_col], errors='coerce')
        df[price_col + '_vs_BB_Upper'] = (price_series > bb_upper_series).astype(int)
        df[price_col + '_vs_BB_Lower'] = (price_series < bb_lower_series).astype(int)
    return df

def add_psar_flip_signal(df, psar_col_name='PSARr_0.02_0.2', close_col='close'): # pandas_ta PSAR reversal column
    if psar_col_name in df.columns: # PSARr is 1 for reversal to uptrend, -1 for reversal to downtrend
        df['PSAR_Flip_Signal'] = pd.to_numeric(df[psar_col_name], errors='coerce').fillna(0).astype(int)
    return df

# Keep these custom functions as they are generally good:
def add_daily_vwap(df, high_col='high', low_col='low', close_col='close', volume_col='volume', new_col_name='VWAP_D'): # Changed name to VWAP_D for daily
    # ... (your existing robust add_daily_vwap function - ensure it uses .copy() and numeric conversions internally)
    # Make sure the final column is named VWAP_D or adjust add_price_vs_ma call later
    if not isinstance(df.index, pd.DatetimeIndex):
        print("Error: DataFrame index must be DatetimeIndex for daily VWAP.")
        return df
    df_temp = df.copy()
    for col in [high_col, low_col, close_col, volume_col]:
        df_temp[col] = pd.to_numeric(df_temp[col], errors='coerce')
    tpv = ((df_temp[high_col] + df_temp[low_col] + df_temp[close_col]) / 3) * df_temp[volume_col]
    cumulative_tpv = tpv.groupby(df_temp.index.date).cumsum()
    cumulative_volume = df_temp[volume_col].groupby(df_temp.index.date).cumsum()
    vwap_series = cumulative_tpv / cumulative_volume
    df[new_col_name] = vwap_series.replace([np.inf, -np.inf], np.nan)
    return df


def add_candle_features(df):
    # ... (your existing add_candle_features function - ensure numeric conversions) ...
    df_temp = df.copy()
    for col in ['open', 'high', 'low', 'close']:
        df_temp[col] = pd.to_numeric(df_temp[col], errors='coerce')
    df['Candle_Range'] = df_temp['high'] - df_temp['low']
    df['Candle_Body'] = (df_temp['close'] - df_temp['open']).abs()
    df['Upper_Wick'] = df_temp['high'] - np.maximum(df_temp['open'], df_temp['close'])
    df['Lower_Wick'] = np.minimum(df_temp['open'], df_temp['close']) - df_temp['low']
    df['Body_vs_Range'] = (df['Candle_Body'] / df['Candle_Range'].replace(0, np.nan)).replace([np.inf, -np.inf], np.nan).fillna(0)
    return df

def add_return_features(df, price_col='close'):
    # ... (your existing add_return_features function - ensure numeric conversions and inf handling) ...
    price_series_num = pd.to_numeric(df[price_col], errors='coerce').replace(0, np.nan)
    df[f'Log_Return_1'] = np.log(price_series_num / price_series_num.shift(1))
    df[f'Log_Return_3'] = np.log(price_series_num / price_series_num.shift(3))
    df[f'Log_Return_6'] = np.log(price_series_num / price_series_num.shift(6))
    df[f'Simple_Return_1'] = price_series_num.pct_change(1)
    for col_ret in [f'Log_Return_1', f'Log_Return_3', f'Log_Return_6', f'Simple_Return_1']:
        if col_ret in df.columns: df[col_ret] = df[col_ret].replace([np.inf, -np.inf], np.nan)
    return df

def add_rolling_stats(df, price_col='close', window1=14, window2=30):
    # ... (your existing add_rolling_stats function - ensure numeric conversions and inf handling) ...
    returns = pd.to_numeric(df[price_col], errors='coerce').pct_change(1).replace([np.inf, -np.inf], np.nan)
    df[f'Rolling_Std_Dev_{window1}'] = returns.rolling(window=window1).std()
    df[f'Rolling_Skew_{window2}'] = returns.rolling(window=window2).skew()
    df[f'Rolling_Kurtosis_{window2}'] = returns.rolling(window=window2).kurt()
    return df

def add_lagged_features(df, cols_to_lag, lags=[1, 3, 6]):
    # ... (your existing add_lagged_features function - ensure numeric conversions on source col if needed) ...
    for col_orig in cols_to_lag:
        if col_orig in df.columns:
            series_to_lag = pd.to_numeric(df[col_orig], errors='coerce')
            for lag in lags:
                df[f'{col_orig}_Lag_{lag}'] = series_to_lag.shift(lag)
    return df


# --- Main Feature Generation Function using pandas_ta ---
def add_all_features(df_input, suffix=''):
    """
    Adds technical indicators and derived features using pandas_ta.
    Assumes df_input has 'open', 'high', 'low', 'close', 'volume' columns (DatetimeIndex).
    """
    if not isinstance(df_input.index, pd.DatetimeIndex):
        print(f"Warning: DataFrame for suffix '{suffix}' does not have a DatetimeIndex.")
    
    df = df_input.copy() # Work on a copy

    # Ensure base OHLCV columns are numeric and present
    base_cols = ['open', 'high', 'low', 'close', 'volume']
    if not all(col in df.columns for col in base_cols):
         raise ValueError(f"DataFrame must contain {base_cols}. Found: {df.columns.tolist()}")
    for col in base_cols: # Ensure correct dtypes for pandas_ta
        df[col] = pd.to_numeric(df[col], errors='coerce')
    df.dropna(subset=base_cols, inplace=True) # Drop rows if OHLCV became NaN

    if df.empty:
        print(f"DataFrame became empty after coercing OHLCV for suffix '{suffix}'. Returning empty DataFrame.")
        # Return an empty dataframe with expected suffixed columns if possible or raise error
        # For simplicity, we'll let it create columns that will be all NaN, then suffixing will apply.
        # Or handle more gracefully by creating expected columns with NaNs.
        # For now, we will proceed, and suffixing will apply to what gets created.
        pass


    print(f"DataFrame shape for pandas_ta (suffix: {suffix}): {df.shape}")

    # I. Technical Indicators using pandas_ta
    # Most pandas_ta functions automatically name columns (e.g., SMA_10, RSI_14)
    # and handle NaNs internally. `append=True` adds them to df.

    # Volume
    df.ta.sma(close=df['volume'], length=20, append=True, col_names=('Volume_SMA_20'))
    df = add_daily_vwap(df, new_col_name='VWAP_D') # Using your custom daily VWAP, named VWAP_D
    df = add_price_vs_ma(df, ma_col_name='VWAP_D', new_col_name_suffix='_vs_VWAP_D')

    # Volatility
    df.ta.bbands(length=20, std=2, append=True) # Creates BBL_20_2.0, BBM_20_2.0, BBU_20_2.0, BBB_20_2.0, BBP_20_2.0
    # Helpers will need these names: BBU_20_2.0, BBL_20_2.0
    df = add_price_vs_bb(df, bb_upper_col='BBU_20_2.0', bb_lower_col='BBL_20_2.0')
    df.ta.atr(length=14, append=True, col_names=('ATR_14')) # pandas_ta might name it ATRr_14 or similar. We force ATR_14.

    # Trend
    df.ta.sma(length=10, append=True) # SMA_10
    df.ta.sma(length=20, append=True) # SMA_20 (also BBM_20_2.0 from bbands)
    df.ta.sma(length=50, append=True) # SMA_50
    df.ta.ema(length=9, append=True) # EMA_10
    df.ta.ema(length=10, append=True) # EMA_10
    df.ta.ema(length=20, append=True) # EMA_20
    df.ta.ema(length=21, append=True) # EMA_10
    df.ta.ema(length=50, append=True) # EMA_50
    df.ta.ema(length=200, append=True) # EMA_50

    df.ta.donchian(lower_length=20, upper_length=20, append=True)
    df.ta.chop(length=14, append=True)

    df = add_price_vs_ma(df, ma_col_name='EMA_200', new_col_name_suffix='_vs_EMA200')
    df = add_price_vs_ma(df, ma_col_name='EMA_20', new_col_name_suffix='_vs_EMA20')
    df = add_ma_vs_ma(df, ma1_col_name='EMA_10', ma2_col_name='EMA_20', new_col_name_suffix='_vs_EMA20')
    df = add_ma_vs_ma(df, ma1_col_name='EMA_9', ma2_col_name='EMA_21', new_col_name_suffix='_vs_EMA21')
    df = add_ma_slope(df, ma_col_name='EMA_10', new_col_name_suffix='_Slope_10')

    df.ta.macd(fast=12, slow=26, signal=9, append=True) # MACD_12_26_9, MACDh_12_26_9, MACDs_12_26_9
    df = add_macd_cross_signal(df, macd_col_name='MACD_12_26_9', signal_col_name='MACDs_12_26_9')

    df.ta.adx(length=14, append=True) # ADX_14, DMP_14, DMN_14
    # Rename DMN_14 and DMP_14 to match your old Minus_DI_14, Plus_DI_14 if helpers depend on it
    if 'DMP_14' in df.columns: df.rename(columns={'DMP_14': 'Plus_DI_14'}, inplace=True)
    if 'DMN_14' in df.columns: df.rename(columns={'DMN_14': 'Minus_DI_14'}, inplace=True)
    
    df.ta.psar(append=True) # Creates PSARl_0.02_0.2, PSARs_0.02_0.2, PSARaf_0.02_0.2, PSARr_0.02_0.2
    df = add_psar_flip_signal(df, psar_col_name='PSARr_0.02_0.2') # Use reversal column

    df.ta.cci(length=20, append=True, col_names=('CCI_20')) # pandas_ta uses CCI_20_0.015 by default

    # Momentum
    df.ta.rsi(length=14, append=True) # RSI_14
    df = add_rsi_signals(df, rsi_col_name='RSI_14')
    df.ta.chop(length=14, append=True)  # Adds column: CHOP_14

    df.ta.willr(length=14, append=True)  # Adds column: WILLR_14

    
    df.ta.stoch(k=14, d=3, smooth_k=3, append=True) # STOCHk_14_3_3, STOCHd_14_3_3
    df = add_stoch_signals(df, stoch_k_col_name='STOCHk_14_3_3')

    df.ta.ppo(fast=12, slow=26, signal=9, append=True) # PPO_12_26_9, PPOh_12_26_9, PPOs_12_26_9
    df.ta.roc(length=10, append=True) # ROC_10
    
    # Explicitly convert PPO and ROC to numeric (belt and braces after pandas_ta)
    for col_name in ['PPO_12_26_9', 'ROC_10']: # Check exact names if pandas_ta produces variants
        base_name_ppo = [c for c in df.columns if "PPO_" in c and "PPOh" not in c and "PPOs" not in c]
        base_name_roc = [c for c in df.columns if "ROC_" in c]
        
        for actual_col_name in base_name_ppo + base_name_roc:
            if actual_col_name in df.columns:
                df[actual_col_name] = df[actual_col_name].replace([np.inf, -np.inf], np.nan)
                df[actual_col_name] = pd.to_numeric(df[actual_col_name], errors='coerce')

    # II. Price Action & Basic Features (Keep your custom functions)
    df = add_candle_features(df)
    # df = add_candlestick_patterns(df) # We'll replace this with pandas_ta candlestick patterns

    # --- pandas_ta Candlestick Patterns ---
    # Example: Add Doji, Hammer, Engulfing. pandas_ta has many more.
    # 'name="all"' would add many columns, so be selective or use a list.
    candle_patterns_to_check = ["doji", "hammer", "engulfing"] 
    df.ta.cdl_pattern(name=candle_patterns_to_check, append=True)
    # Rename columns to match your old convention if needed, e.g., CDLDOJI -> Is_Doji
    if 'CDLDOJI' in df.columns: df.rename(columns={'CDLDOJI': 'Is_Doji_pta'}, inplace=True) # Add _pta to distinguish
    if 'CDLHAMMER' in df.columns: df.rename(columns={'CDLHAMMER': 'Is_Hammer_pta'}, inplace=True)
    if 'CDLENGULFING' in df.columns: df.rename(columns={'CDLENGULFING': 'Is_Engulfing_pta'}, inplace=True) # This is a general engulfing signal (+/-)

    df = add_return_features(df)

    # III. Statistical Features (Keep your custom functions)
    df = add_rolling_stats(df)
    
    # Lagged Features
    # Ensure base columns for lagging are the ones created by pandas_ta or your helpers
    cols_to_lag_pta = ['close', 'RSI_14', 'Candle_Body', 'Volume_SMA_20'] 
    # Check if these columns actually exist, as pandas_ta might name them slightly differently
    # This valid_cols_to_lag should use the names as they are in df at this point
    valid_cols_to_lag = [col for col in cols_to_lag_pta if col in df.columns]
    df = add_lagged_features(df, valid_cols_to_lag, lags=[1,2,3])

    # --- Suffixing ---
    # All columns created by pandas_ta (that were appended) or by helpers
    # that are not the original 'open', 'high', 'low', 'close', 'volume' will be suffixed.
    current_cols = list(df.columns)
    # Identify features generated in this function call (not the original base OHLCV)
    generated_feature_cols = [col for col in current_cols if col not in base_cols]
    
    rename_dict = {col: col + suffix for col in generated_feature_cols}
    df.rename(columns=rename_dict, inplace=True)
    
    return df

# --- Time & Session Features (Keep as is) ---
def add_time_session_features(df):
    # ... (your existing add_time_session_features function) ...
    if not isinstance(df.index, pd.DatetimeIndex):
        print("Error: DataFrame index must be DatetimeIndex for time/session features.")
        return df
    df = df.copy()
    df['Hour_of_Day'] = df.index.hour
    df['Minute_of_Hour'] = df.index.minute
    df['Day_of_Week'] = df.index.dayofweek
    time_fraction_of_day = df['Hour_of_Day'] + df['Minute_of_Hour'] / 60.0
    df['Time_Sin'] = np.sin(2 * np.pi * time_fraction_of_day / 24.0)
    df['Time_Cos'] = np.cos(2 * np.pi * time_fraction_of_day / 24.0)
    df['Day_Sin'] = np.sin(2 * np.pi * df['Day_of_Week'] / 7.0)
    df['Day_Cos'] = np.cos(2 * np.pi * df['Day_of_Week'] / 7.0)
    df['Is_Asian_Session'] = ((df['Hour_of_Day'] >= 20) | (df['Hour_of_Day'] < 5)).astype(int)
    df['Is_London_Session'] = ((df['Hour_of_Day'] >= 3) & (df['Hour_of_Day'] < 12)).astype(int)
    df['Is_NY_Session'] = ((df['Hour_of_Day'] >= 8) & (df['Hour_of_Day'] < 17)).astype(int)
    df['Is_Overlap'] = ((df['Hour_of_Day'] >= 8) & (df['Hour_of_Day'] < 12)).astype(int)
    df['Is_US_Open_Hour'] = ((df['Hour_of_Day'] == 9) & (df['Minute_of_Hour'] >= 30) | (df['Hour_of_Day'] == 10) & (df['Minute_of_Hour'] < 30)).astype(int)
    df['Is_US_Close_Hour'] = ((df['Hour_of_Day'] == 15) | (df['Hour_of_Day'] == 16) & (df['Minute_of_Hour'] == 0)).astype(int)
    return df

# %%
avoid_funcs = {
    #'avoid_hour_18_19': avoid_hour_18_19
    #'news_window': avoid_news,
}

param_grid_strategy = {
    'SL_ATR_MULT': [0.5, 0.3, 0.2, 0.1],
    'TP_ATR_MULT': [2.0, 4.0, 8.0, 10.0, 15.0, 20.0],
    'TRAIL_START_MULT': [0.5, 1.0, 0.3],
    'TRAIL_STOP_MULT': [0.5, 1.0, 0.3],
    'TICK_VALUE': [20], 
}

keys, values = zip(*param_grid_strategy.items())
combinations = [dict(zip(keys, v)) for v in product(*values)]

# %% [markdown]
# # Cleanup

# %%
df_1min, resampled = load_and_resample_data(market, timeframes=['5min', '15min','1h'])

df_5min = resampled['5min']
df_15min = resampled['15min']
df_1hr = resampled['1h']

print("5min shape:", df_5min.shape)
print("15min shape:", df_15min.shape)
print("1h shape:", df_1hr.shape)


df_merged = apply_feature_engineering(
    resampled=resampled,
    add_all_features=add_all_features,
    add_time_session_features=add_time_session_features,
    timeframes=['5min', '15min', '1h'],
    base_tf='5min'
)

# Verify Data
# def check_feature_alignment(df_merged, tf_suffix, feature_keyword, sample_times):
#     """
#     Check if features from the correct timeframe are available and what values they have at key timestamps.
#     """
#     suffix_str = f"_{tf_suffix}"
#     matching_cols = [col for col in df_merged.columns if feature_keyword in col and col.endswith(suffix_str)]
    
#     print(f"\n🔍 Checking features containing '{feature_keyword}' with suffix '{suffix_str}'")

#     if not matching_cols:
#         print(f"⚠️ No matching columns found. Available columns ending with {suffix_str}:")
#         sample_suffix_cols = [col for col in df_merged.columns if col.endswith(suffix_str)]
#         print(sample_suffix_cols[:10])  # Show only first 10 to keep it clean
#         return

#     for time in sample_times:
#         if time not in df_merged.index:
#             print(f"❌ Time {time} not found in df_merged index.")
#         else:
#             print(f"\n⏰ At time {time} — values:")
#             print(df_merged.loc[time, matching_cols])

# sample_times = [
#     pd.Timestamp("2022-01-05 12:05:00-05:00"),
#     pd.Timestamp("2022-01-05 12:15:00-05:00"),
#     pd.Timestamp("2022-01-05 12:59:00-05:00"),
#     pd.Timestamp("2022-01-05 13:00:00-05:00")
# ]

# check_feature_alignment(df_merged, tf_suffix="1h", feature_keyword="RSI", sample_times=sample_times)
# check_feature_alignment(df_merged, tf_suffix="15min", feature_keyword="MACD", sample_times=sample_times)
# check_feature_alignment(df_merged, tf_suffix="5min", feature_keyword="EMA", sample_times=sample_times)
# Out:
# 📁 Found matching folder: ./../data/BTCUSDT_1m
# 5min shape: (818107, 5)
# 15min shape: (272726, 5)
# 1h shape: (68203, 5)
# --- Starting Feature Engineering Execution ---
#
# Generating features for timeframe: 5min — shape: (818107, 5)
# DataFrame shape for pandas_ta (suffix: _5min): (818107, 5)
# /Users/francopapalardo-aleo/.pyenv/versions/3.12.10/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/francopapalardo-aleo/.pyenv/versions/3.12.10/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Output shape for 5min: (818107, 86)
#
# Generating features for timeframe: 15min — shape: (272726, 5)
# DataFrame shape for pandas_ta (suffix: _15min): (272726, 5)
# Output shape for 15min: (272726, 86)
#
# Generating features for timeframe: 1h — shape: (68203, 5)
# DataFrame shape for pandas_ta (suffix: _1h): (68203, 5)
# Output shape for 1h: (68203, 86)
#
# Adding time/session features to base timeframe: 5min
#
# Merging additional timeframe features into base...
# --- Feature Engineering Execution COMPLETE ---
# Final df_merged shape: (818107, 261)

# %%
labeled = label_and_save(
    df_input_features=df_merged,
    lookahead_period=LOOK_AHEAD,
    vol_col_name='ATR_14_5min',
    pt_multiplier=2.0,
    sl_multiplier=1.0,
    min_return_percentage=0.0005,
    output_file_suffix=f'L{LOOK_AHEAD}_PT2SL1VB{LOOK_AHEAD}{market}',
    feature_columns_for_dropna=[]
)
# Out:
# --- Processing for output suffix: L12_PT2SL1VB12BTC ---
# Adding Regression Target: reg_target_lookahead12 ...
# reg_target_lookahead12 NaNs: 34153
#
# Adding Classification Target: clf_target_numba_pt2.0sl1.0vb12 ...
# clf_target_numba_pt2.0sl1.0vb12 NaNs: 0
# Rows after dropping NaNs from targets: 783954
# ✅ Saved parquet/labeled_data_L12_PT2SL1VB12BTC.parquet with 783954 rows

# %% [markdown]
# # Train

# %% [markdown]
# ##### Real Training

# %%
INDICATOR_FEATURES = [

    # === 5min Features ===
    "EMA_9_5min", "EMA_21_5min",
    "MACD_12_26_9_5min", "MACDh_12_26_9_5min",
    "RSI_14_5min", "ADX_14_5min", "ATR_14_5min",
    "Volume_SMA_20_5min",
    "VWAP_D_5min", "close_vs_VWAP_D_5min",
    "DCU_20_20_5min", "DCL_20_20_5min",
    "close_vs_EMA20_5min", "EMA_9_vs_EMA21_5min",
    "CHOP_14_1_100_5min",

    # === 15min Features ===
    "EMA_20_15min", "EMA_50_15min",
    "MACD_12_26_9_15min", "MACDh_12_26_9_15min",
    "RSI_14_15min", "ADX_14_15min", "ATR_14_15min",
    "VWAP_D_15min", "DCU_20_20_15min", "DCL_20_20_15min",
    "close_vs_EMA20_15min",

    # === 1h Features ===
    "EMA_50_1h", "EMA_200_1h",
    "MACD_12_26_9_1h", "MACDh_12_26_9_1h",
    "RSI_14_1h", "ADX_14_1h", "ATR_14_1h",
    "VWAP_D_1h", "CHOP_14_1_100_1h",
    "DCU_20_20_1h", "DCL_20_20_1h",
    "close_vs_EMA200_1h"
]

# %%
def run_lookahead_for_session_regression(LOOKAHEAD):
    # === Load data ===
    path = f"parquet/labeled_data_L{LOOKAHEAD}_PT2SL1VB{LOOKAHEAD}{market}.parquet"
    labeled = pd.read_parquet(path)

    # === Ensure datetime column exists and is parsed ===
    if labeled.index.name == 'datetime' or pd.api.types.is_datetime64_any_dtype(labeled.index):
        labeled = labeled.reset_index()
    if 'datetime' not in labeled.columns:
        raise KeyError("❌ 'datetime' column is missing.")
    
    labeled['datetime'] = pd.to_datetime(labeled['datetime'])
    labeled = labeled.sort_values('datetime')

    # === Train/test split ===
    cutoff_date = pd.Timestamp("2024-01-01", tz="America/New_York")
    train = labeled[labeled['datetime'] < cutoff_date]
    print(train.columns.to_list())
    test = labeled[labeled['datetime'] >= cutoff_date]

    train = train.set_index('datetime')
    test = test.set_index('datetime')

    # === Feature selection ===
    X_train_tree = train[INDICATOR_FEATURES]
    X_test_tree = test[INDICATOR_FEATURES]

    # === Find regression target column ===
    reg_cols = [col for col in labeled.columns if col.startswith("reg_target")]
    if not reg_cols:
        raise ValueError("❌ No regression target column found starting with 'reg_target'.")
    reg_col = reg_cols[0]
    print(f"📌 Using regression target column: {reg_col}")

    y_train_seq = train[reg_col]
    y_test_seq = test[reg_col]

    print(f"Train range: {train.index.min()} to {train.index.max()} | Rows: {len(train)}")
    print(f"Test range: {test.index.min()} to {test.index.max()} | Rows: {len(test)}")

    ###########################
    ########## Models #########
    ###########################

    def tune_catboost_regressor(X, y):
        def objective(trial):
            params = {
                "iterations": trial.suggest_int("iterations", 100, 1000, step=100),
                "depth": trial.suggest_int("depth", 4, 10),
                "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
                "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1.0, 10.0),
                "random_strength": trial.suggest_float("random_strength", 0.5, 5.0),
                "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 10, 100),
            }
            model = CatBoostRegressor(**params, verbose=0)
            scores = cross_val_score(model, X, y, cv=TimeSeriesSplit(n_splits=3), scoring="neg_mean_squared_error", n_jobs=-4)
            return scores.mean()
        study = optuna.create_study(direction="maximize", study_name=f"catboost-test{LOOKAHEAD}{market}", storage="sqlite:///dbs/catboost-test.db", load_if_exists=True)
        study.optimize(objective, n_trials=100)
        return study.best_trial.params
    
    # def tune_catboost2_regressor(X, y):
    #     def objective(trial):
    #         params = {
    #             "iterations": trial.suggest_int("iterations", 100, 1000, step=100),
    #             "depth": trial.suggest_int("depth", 4, 10),
    #             "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
    #             "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1.0, 10.0),
    #             "random_strength": trial.suggest_float("random_strength", 0.5, 5.0),
    #             "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 10, 100),
    #         }
    #         model = CatBoostRegressor(**params, verbose=0)
    #         scores = cross_val_score(model, X, y, cv=TimeSeriesSplit(n_splits=3), scoring="neg_mean_squared_error", n_jobs=-4)
    #         return scores.mean()
    #     study = optuna.create_study(direction="maximize", study_name=f"catboost2-test{LOOKAHEAD}{market}", storage="sqlite:///dbs/catboost-test.db", load_if_exists=True)
    #     study.optimize(objective, n_trials=1)
    #     return study.best_trial.params
    
    def tune_meta_catboost_regressor(X, y):
        def objective(trial):
            params = {
                "iterations": trial.suggest_int("iterations", 50, 500, step=50),
                "depth": trial.suggest_int("depth", 2, 6),
                "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1, log=True),
                "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1.0, 5.0),
                "random_strength": trial.suggest_float("random_strength", 0.1, 2.0),
                "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 20),
            }
            model = CatBoostRegressor(**params, verbose=0)
            scores = cross_val_score(
                model, X, y,
                cv=TimeSeriesSplit(n_splits=3),
                scoring="neg_mean_squared_error",
                n_jobs=-4
            )
            return scores.mean()

        study = optuna.create_study(
            direction="maximize",
            study_name=f"meta-catboost-stack-{LOOKAHEAD}{market}",
            storage="sqlite:///dbs/meta_catboost.db",
            load_if_exists=True
        )
        study.optimize(objective, n_trials=20)
        return study.best_trial.params

    ################################################
    ####### Ensure index consistency
    ####### Sequential #######

    ################################################
    ####### Tune models
    ####### Tree Based #######
    catboost_params     = tune_catboost_regressor(X_train_tree, y_train_seq)
    # catboost_2_params         = tune_catboost2_regressor(X_train_cat2, y_train_seq)
    ####### Sequential #######
    # N/A

    ################################################
    ####### Train models
    ####### Tree Based #######
    catboost    = CatBoostRegressor(**catboost_params, random_state=42, verbose=0)
    # catboost2        = CatBoostRegressor(**catboost_2_params, random_state=42, verbose=0)
    catboost.fit(X_train_tree, y_train_seq)
    # catboost2.fit(X_train_cat2, y_train_seq)
    ################################################
    ####### OOF Predicition
    ####### Tree Based #######
    oof_cat = generate_oof_predictions([catboost], X_train_tree, y_train_seq, 3)
    # oof_cat2 = generate_oof_predictions([catboost2], X_train_cat2, y_train_seq, 3)

    print("\n🔍 Checking variance in OOF base model predictions Catboost model:")
    print(oof_cat.describe())
    print("Std per model:\n", oof_cat.std())

    # print("\n🔍 Checking variance in OOF base model predictions LGBM model:")
    # print(oof_cat2.describe())
    # print("Std per model:\n", oof_cat2.std())

    ################################################
    ####### Evaluate Model
    def evaluate_model(name, model, Xtr, Xte, ytr, yte, transformed=False):
        train_preds = model.predict(Xtr)
        test_preds = model.predict(Xte)

        if transformed:
        # Inverse-transform predictions
            train_preds = np.sign(train_preds) * (np.expm1(np.abs(train_preds)))
            test_preds = np.sign(test_preds) * (np.expm1(np.abs(test_preds)))
            ytr = np.sign(ytr) * (np.expm1(np.abs(ytr)))
        
        train_mse = mean_squared_error(ytr, train_preds)
        test_mse = mean_squared_error(yte, test_preds)
        overfit_ratio = test_mse / train_mse if train_mse != 0 else float('inf')

        print(f"\n📊 {name} Performance:")
        print(f"Train MSE: {train_mse:.8f}")
        print(f"Test MSE: {test_mse:.8f}")
        print(f"Overfit ratio (Test / Train): {overfit_ratio:.2f}")
        if overfit_ratio > 1.5:
            print("⚠️ Potential overfitting detected.")
        elif overfit_ratio < 0.7:
            print("⚠️ Possibly underfitting.")
        else:
            print("✅ Generalization looks reasonable.")
        return test_preds
    
    ####### Tree Based #######
    print("\nEvaluation CatBoost")
    preds_catboost  = evaluate_model("CatBoostRegressor", catboost, X_train_tree, X_test_tree, y_train_seq, y_test_seq, transformed=True)

    # print("\nEvaluation LGBM")
    # preds_catboost2  = evaluate_model("CatBoostRegressor2", catboost2, X_train_cat2, X_test_cat2, y_train_seq, y_test_seq, transformed=True)

    
    # # === Combine into X_meta_train using original OOF indices (from TSCV)
    # X_meta_train = pd.DataFrame({
    #     "cat_pred": oof_cat.iloc[:, 0],
    #     "cat2_pred": oof_cat2.iloc[:, 0]
    # })

    # X_meta_test = pd.DataFrame({
    #     "cat_pred": preds_catboost,
    #     "cat2_pred": preds_catboost2
    # })

    # scaler = RobustScaler()
    # X_meta_train_scaled = pd.DataFrame(scaler.fit_transform(X_meta_train), columns=X_meta_train.columns, index=X_meta_train.index)
    # X_meta_test_scaled = pd.DataFrame(scaler.transform(X_meta_test), columns=X_meta_test.columns, index=X_meta_test.index)


    # # === Tune and train meta model
    # meta_params = tune_meta_catboost_regressor(X_meta_train_scaled, y_train_seq)
    # meta_model = CatBoostRegressor(**meta_params, random_state=42, verbose=0)
    # meta_model.fit(X_meta_train_scaled, y_train_seq)

    # # === Predict using meta model
    # preds_stack = evaluate_model(
    #     "MetaModel",
    #     meta_model,
    #     X_meta_train_scaled,
    #     X_meta_test_scaled,
    #     y_train_seq,
    #     y_test_seq,
    #     transformed=True
    # )

    ################################################
    ####### Target Distribution
    ####### Sequential #######
    print("\n🔍 Target distribution Seq:")
    print(y_train_seq.describe())
    
    ################################################
    ####### Choose final model
    ####### Tree Based #######
    print("\n🔍 Checking prediction variance from Catboost:")
    print(f"Min: {preds_catboost.min():.8f}")
    print(f"Max: {preds_catboost.max():.8f}")
    print(f"Mean: {preds_catboost.mean():.8f}")
    print(f"Std Dev: {preds_catboost.std():.8f}")
    print(f"First 5 Predictions: {preds_catboost[:5]}")

    mae = mean_absolute_error(y_test_seq, preds_catboost)
    rmse = np.sqrt(mean_squared_error(y_test_seq, preds_catboost))
    r2 = r2_score(y_test_seq, preds_catboost)

    print(f"MAE: {mae:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"R²: {r2:.4f}")
    ####
    # print("\n🔍 Checking prediction variance from LGBM:")
    # print(f"Min: {preds_catboost2.min():.8f}")
    # print(f"Max: {preds_catboost2.max():.8f}")
    # print(f"Mean: {preds_catboost2.mean():.8f}")
    # print(f"Std Dev: {preds_catboost2.std():.8f}")
    # print(f"First 5 Predictions: {preds_catboost2[:5]}")

    # mae_cat2 = mean_absolute_error(y_test_seq, preds_catboost2)
    # rmse_cat2= np.sqrt(mean_squared_error(y_test_seq, preds_catboost2))
    # r2_cat2 = r2_score(y_test_seq, preds_catboost2)

    # print(f"MAE: {mae_cat2:.4f}")
    # print(f"RMSE: {rmse_cat2:.4f}")
    # print(f"R²: {r2_cat2:.4f}")
    # ###
    # print("\n🔍 Checking prediction variance from Meta Model:")
    # print(f"Min: {preds_stack.min():.8f}")
    # print(f"Max: {preds_stack.max():.8f}")
    # print(f"Mean: {preds_stack.mean():.8f}")
    # print(f"Std Dev: {preds_stack.std():.8f}")
    # print(f"First 5 Predictions: {preds_stack[:5]}")

    # mae_meta = mean_absolute_error(y_test_seq, preds_stack)
    # rmse_meta = np.sqrt(mean_squared_error(y_test_seq, preds_stack))
    # r2_meta = r2_score(y_test_seq, preds_stack)

    # print(f"MAE: {mae_meta:.4f}")
    # print(f"RMSE: {rmse_meta:.4f}")
    # print(f"R²: {r2_meta:.4f}")
    ###

    # === Ensure datetime is preserved ===
    X_test_tree = X_test_tree.copy()
    X_test_tree["datetime"] = X_test_tree.index

    metadata = {
        "lookahead": LOOKAHEAD,
        "catboost_params": catboost_params,
        # "lgbm_params": catboost_2_params,
        # "meta_params": meta_params
    }
    with open(f"regression_metadata_{LOOKAHEAD}.json", "w") as f:
        json.dump(metadata, f, indent=2)

    joblib.dump(list(X_train_tree.columns), f"pkl/model_cat_feature_{market}-12&24-single-model-less-features.pkl")
    # joblib.dump(list(X_train_cat2.columns), f"pkl/model_cat2_feature_{market}-12&24-single-model-less-features.pkl")
    # joblib.dump(meta_model, f"pkl/stack_model_regression_NQ-12&24-single-model-less-features.pkl")
    joblib.dump(catboost, f"pkl/catboost_model_regression_{market}-12&24-single-model-less-features.pkl")
    # joblib.dump(catboost2, f"pkl/lgbm_model_regression_{market}-12&24-single-model-less-features.pkl")

    return {
        'lookahead': LOOKAHEAD,
        # 'preds_stack': preds_stack,
        'preds_catboost': preds_catboost,
        # 'preds_lgbm': preds_catboost2,
        # 'X_test_cat2': X_test_cat2,
        'X_test_tree': X_test_tree,  # ✅ now has datetime column preserved
        'true_values': y_test_seq
    }

# %% [markdown]
# ##### Running Train

# %%
# Regression Training
lookahead_values = [LOOK_AHEAD]
reg_results = []


os.makedirs("data", exist_ok=True)

for val in lookahead_values:
    regression_models = run_lookahead_for_session_regression(val)
    reg_results.append(regression_models)
# Out:
# ['datetime', 'open', 'high', 'low', 'close', 'volume', 'Volume_SMA_20_5min', 'VWAP_D_5min', 'close_vs_VWAP_D_5min', 'BBL_20_2.0_5min', 'BBM_20_2.0_5min', 'BBU_20_2.0_5min', 'BBB_20_2.0_5min', 'BBP_20_2.0_5min', 'close_vs_BB_Upper_5min', 'close_vs_BB_Lower_5min', 'ATR_14_5min', 'SMA_10_5min', 'SMA_20_5min', 'SMA_50_5min', 'EMA_9_5min', 'EMA_10_5min', 'EMA_20_5min', 'EMA_21_5min', 'EMA_50_5min', 'EMA_200_5min', 'DCL_20_20_5min', 'DCM_20_20_5min', 'DCU_20_20_5min', 'CHOP_14_1_100_5min', 'close_vs_EMA200_5min', 'close_vs_EMA20_5min', 'EMA_10_vs_EMA20_5min', 'EMA_9_vs_EMA21_5min', '_Slope_10_5min', 'MACD_12_26_9_5min', 'MACDh_12_26_9_5min', 'MACDs_12_26_9_5min', 'MACD_12_26_9_Cross_Signal_5min', 'ADX_14_5min', 'Plus_DI_14_5min', 'Minus_DI_14_5min', 'PSARl_0.02_0.2_5min', 'PSARs_0.02_0.2_5min', 'PSARaf_0.02_0.2_5min', 'PSARr_0.02_0.2_5min', 'PSAR_Flip_Signal_5min', 'CCI_20_5min', 'RSI_14_5min', 'RSI_14_Is_Overbought_70_5min', 'RSI_14_Is_Oversold_30_5min', 'WILLR_14_5min', 'STOCHk_14_3_3_5min', 'STOCHd_14_3_3_5min', 'STOCHk_14_3_3_Is_Overbought_80_5min', 'STOCHk_14_3_3_Is_Oversold_20_5min', 'PPO_12_26_9_5min', 'PPOh_12_26_9_5min', 'PPOs_12_26_9_5min', 'ROC_10_5min', 'Candle_Range_5min', 'Candle_Body_5min', 'Upper_Wick_5min', 'Lower_Wick_5min', 'Body_vs_Range_5min', 'CDL_DOJI_10_0.1_5min', 'CDL_HAMMER_5min', 'CDL_ENGULFING_5min', 'Log_Return_1_5min', 'Log_Return_3_5min', 'Log_Return_6_5min', 'Simple_Return_1_5min', 'Rolling_Std_Dev_14_5min', 'Rolling_Skew_30_5min', 'Rolling_Kurtosis_30_5min', 'close_Lag_1_5min', 'close_Lag_2_5min', 'close_Lag_3_5min', 'RSI_14_Lag_1_5min', 'RSI_14_Lag_2_5min', 'RSI_14_Lag_3_5min', 'Candle_Body_Lag_1_5min', 'Candle_Body_Lag_2_5min', 'Candle_Body_Lag_3_5min', 'Volume_SMA_20_Lag_1_5min', 'Volume_SMA_20_Lag_2_5min', 'Volume_SMA_20_Lag_3_5min', 'Hour_of_Day', 'Minute_of_Hour', 'Day_of_Week', 'Time_Sin', 'Time_Cos', 'Day_Sin', 'Day_Cos', 'Is_Asian_Session', 'Is_London_Session', 'Is_NY_Session', 'Is_Overlap', 'Is_US_Open_Hour', 'Is_US_Close_Hour', 'Volume_SMA_20_15min', 'VWAP_D_15min', 'close_vs_VWAP_D_15min', 'BBL_20_2.0_15min', 'BBM_20_2.0_15min', 'BBU_20_2.0_15min', 'BBB_20_2.0_15min', 'BBP_20_2.0_15min', 'close_vs_BB_Upper_15min', 'close_vs_BB_Lower_15min', 'ATR_14_15min', 'SMA_10_15min', 'SMA_20_15min', 'SMA_50_15min', 'EMA_9_15min', 'EMA_10_15min', 'EMA_20_15min', 'EMA_21_15min', 'EMA_50_15min', 'EMA_200_15min', 'DCL_20_20_15min', 'DCM_20_20_15min', 'DCU_20_20_15min', 'CHOP_14_1_100_15min', 'close_vs_EMA200_15min', 'close_vs_EMA20_15min', 'EMA_10_vs_EMA20_15min', 'EMA_9_vs_EMA21_15min', '_Slope_10_15min', 'MACD_12_26_9_15min', 'MACDh_12_26_9_15min', 'MACDs_12_26_9_15min', 'MACD_12_26_9_Cross_Signal_15min', 'ADX_14_15min', 'Plus_DI_14_15min', 'Minus_DI_14_15min', 'PSARl_0.02_0.2_15min', 'PSARs_0.02_0.2_15min', 'PSARaf_0.02_0.2_15min', 'PSARr_0.02_0.2_15min', 'PSAR_Flip_Signal_15min', 'CCI_20_15min', 'RSI_14_15min', 'RSI_14_Is_Overbought_70_15min', 'RSI_14_Is_Oversold_30_15min', 'WILLR_14_15min', 'STOCHk_14_3_3_15min', 'STOCHd_14_3_3_15min', 'STOCHk_14_3_3_Is_Overbought_80_15min', 'STOCHk_14_3_3_Is_Oversold_20_15min', 'PPO_12_26_9_15min', 'PPOh_12_26_9_15min', 'PPOs_12_26_9_15min', 'ROC_10_15min', 'Candle_Range_15min', 'Candle_Body_15min', 'Upper_Wick_15min', 'Lower_Wick_15min', 'Body_vs_Range_15min', 'CDL_DOJI_10_0.1_15min', 'CDL_HAMMER_15min', 'CDL_ENGULFING_15min', 'Log_Return_1_15min', 'Log_Return_3_15min', 'Log_Return_6_15min', 'Simple_Return_1_15min', 'Rolling_Std_Dev_14_15min', 'Rolling_Skew_30_15min', 'Rolling_Kurtosis_30_15min', 'close_Lag_1_15min', 'close_Lag_2_15min', 'close_Lag_3_15min', 'RSI_14_Lag_1_15min', 'RSI_14_Lag_2_15min', 'RSI_14_Lag_3_15min', 'Candle_Body_Lag_1_15min', 'Candle_Body_Lag_2_15min', 'Candle_Body_Lag_3_15min', 'Volume_SMA_20_Lag_1_15min', 'Volume_SMA_20_Lag_2_15min', 'Volume_SMA_20_Lag_3_15min', 'Volume_SMA_20_1h', 'VWAP_D_1h', 'close_vs_VWAP_D_1h', 'BBL_20_2.0_1h', 'BBM_20_2.0_1h', 'BBU_20_2.0_1h', 'BBB_20_2.0_1h', 'BBP_20_2.0_1h', 'close_vs_BB_Upper_1h', 'close_vs_BB_Lo ...
# [I 2025-06-02 16:26:51,426] Using an existing study with name 'catboost-test12BTC' instead of creating a new one.
# 📌 Using regression target column: reg_target_lookahead12
# Train range: 2017-08-17 00:00:00-04:00 to 2023-12-31 23:55:00-05:00 | Rows: 640859
# Test range: 2024-01-01 00:00:00-05:00 to 2025-06-02 11:30:00-04:00 | Rows: 143095
# [I 2025-06-02 16:26:58,731] Trial 40 finished with value: -3.5310314689156836e-08 and parameters: {'iterations': 100, 'depth': 7, 'learning_rate': 0.012736927638113786, 'l2_leaf_reg': 3.4688102129233784, 'random_strength': 3.228200980663399, 'min_data_in_leaf': 48}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:27:04,602] Trial 41 finished with value: -3.531556937245349e-08 and parameters: {'iterations': 100, 'depth': 7, 'learning_rate': 0.013343317676083672, 'l2_leaf_reg': 3.3740294715912595, 'random_strength': 3.2231692965989267, 'min_data_in_leaf': 49}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:27:19,644] Trial 42 finished with value: -3.53373009209137e-08 and parameters: {'iterations': 200, 'depth': 9, 'learning_rate': 0.012178832552416308, 'l2_leaf_reg': 3.708353159809467, 'random_strength': 3.607110109757901, 'min_data_in_leaf': 46}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:27:26,326] Trial 43 finished with value: -3.531628898286809e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.015886328882342444, 'l2_leaf_reg': 1.693441040042786, 'random_strength': 2.997758000657555, 'min_data_in_leaf': 37}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:27:40,179] Trial 44 finished with value: -3.5439879325485476e-08 and parameters: {'iterations': 200, 'depth': 9, 'learning_rate': 0.020280049379533583, 'l2_leaf_reg': 2.703321315346131, 'random_strength': 4.262289981242888, 'min_data_in_leaf': 50}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:27:45,224] Trial 45 finished with value: -3.530912230295015e-08 and parameters: {'iterations': 100, 'depth': 7, 'learning_rate': 0.013159212024014919, 'l2_leaf_reg': 4.54163187539141, 'random_strength': 3.302737941903586, 'min_data_in_leaf': 59}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:27:59,332] Trial 46 finished with value: -3.539549735328804e-08 and parameters: {'iterations': 300, 'depth': 7, 'learning_rate': 0.012795904023805673, 'l2_leaf_reg': 3.8289394973580837, 'random_strength': 3.9972233762354077, 'min_data_in_leaf': 59}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:28:04,570] Trial 47 finished with value: -3.5322316324093776e-08 and parameters: {'iterations': 100, 'depth': 7, 'learning_rate': 0.01602152740098707, 'l2_leaf_reg': 1.4711370790669303, 'random_strength': 3.376020237564291, 'min_data_in_leaf': 67}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:28:13,590] Trial 48 finished with value: -3.5354201441194814e-08 and parameters: {'iterations': 200, 'depth': 6, 'learning_rate': 0.019601450925450094, 'l2_leaf_reg': 5.195882792734915, 'random_strength': 3.1711246886719433, 'min_data_in_leaf': 53}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:28:21,472] Trial 49 finished with value: -3.540286927463579e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.04181276895876957, 'l2_leaf_reg': 2.7760881069620718, 'random_strength': 4.353438334014426, 'min_data_in_leaf': 65}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:28:32,452] Trial 50 finished with value: -3.542128209209322e-08 and parameters: {'iterations': 200, 'depth': 7, 'learning_rate': 0.024392214633168163, 'l2_leaf_reg': 1.9753651035314808, 'random_strength': 2.421308563713727, 'min_data_in_leaf': 73}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:28:47,659] Trial 51 finished with value: -3.5310359757576555e-08 and parameters: {'iterations': 100, 'depth': 10, 'learning_rate': 0.011840105501234346, 'l2_leaf_reg': 4.278862156523457, 'random_strength': 2.7958871190853416, 'min_data_in_leaf': 43}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:29:03,055] Trial 52 finished with value: -3.53124942690277e-08 and parameters: {'iterations': 100, 'depth': 10, 'learning_rate': 0.011719724418226394, 'l2_leaf_reg': 3.554083576297383, 'random_strength': 2.7054027344982634, 'min_data_in_leaf': 43}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:29:20,872] Trial 53 finished with value: -3.5345792283766404e-08 and parameters: {'iterations': 100, 'depth': 10, 'learning_rate': 0.01609564066046663, 'l2_leaf_reg': 4.4108302516018, 'random_strength': 2.875343296585715, 'min_data_in_leaf': 57}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:29:28,772] Trial 54 finished with value: -3.53277876113185e-08 and parameters: {'iterations': 200, 'depth': 6, 'learning_rate': 0.013598078449985205, 'l2_leaf_reg': 5.755856014401805, 'random_strength': 3.5579041855375007, 'min_data_in_leaf': 31}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:30:15,370] Trial 55 finished with value: -3.545409878286817e-08 and parameters: {'iterations': 300, 'depth': 10, 'learning_rate': 0.011795028602353019, 'l2_leaf_reg': 4.072132210398757, 'random_strength': 3.217554894880687, 'min_data_in_leaf': 39}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:30:21,910] Trial 56 finished with value: -3.595133208725304e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.1133625822127679, 'l2_leaf_reg': 4.889034509091493, 'random_strength': 3.056948790378869, 'min_data_in_leaf': 52}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:30:26,828] Trial 57 finished with value: -3.531730509606727e-08 and parameters: {'iterations': 100, 'depth': 6, 'learning_rate': 0.017020271892438717, 'l2_leaf_reg': 2.898122574824159, 'random_strength': 2.6476383053060797, 'min_data_in_leaf': 43}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:30:45,052] Trial 58 finished with value: -3.53952356415815e-08 and parameters: {'iterations': 600, 'depth': 4, 'learning_rate': 0.014545242428747678, 'l2_leaf_reg': 4.582821018410133, 'random_strength': 3.7545958034667812, 'min_data_in_leaf': 10}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:30:52,235] Trial 59 finished with value: -3.535531596487307e-08 and parameters: {'iterations': 200, 'depth': 5, 'learning_rate': 0.022463268487913846, 'l2_leaf_reg': 2.260609938942648, 'random_strength': 3.351261637501268, 'min_data_in_leaf': 62}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:31:10,675] Trial 60 finished with value: -3.5521793738903966e-08 and parameters: {'iterations': 400, 'depth': 7, 'learning_rate': 0.018553886311476288, 'l2_leaf_reg': 5.5270819566219975, 'random_strength': 2.0587259115587084, 'min_data_in_leaf': 36}. Best is trial 34 with value: -3.530189193975644e-08.
# [I 2025-06-02 16:31:17,931] Trial 61 finished with value: -3.5295777051624156e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.010544446140154144, 'l2_leaf_reg': 4.1771506754231424, 'random_strength': 3.5052830372463797, 'min_data_in_leaf': 48}. Best is trial 61 with value: -3.5295777051624156e-08.
# [I 2025-06-02 16:31:25,303] Trial 62 finished with value: -3.529696556845356e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.011296727506719567, 'l2_leaf_reg': 4.199668777735939, 'random_strength': 3.5003261632600595, 'min_data_in_leaf': 59}. Best is trial 61 with value: -3.5295777051624156e-08.
# [I 2025-06-02 16:31:32,951] Trial 63 finished with value: -3.5299245147326306e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.011274783405634732, 'l2_leaf_reg': 3.872984957876041, 'random_strength': 3.5507057295183695, 'min_data_in_leaf': 58}. Best is trial 61 with value: -3.5295777051624156e-08.
# [I 2025-06-02 16:31:46,662] Trial 64 finished with value: -3.5329425131454734e-08 and parameters: {'iterations': 200, 'depth': 9, 'learning_rate': 0.01003126857067982, 'l2_leaf_reg': 3.881227334781814, 'random_strength': 3.5044771371000154, 'min_data_in_leaf': 64}. Best is trial 61 with value: -3.5295777051624156e-08.
# [I 2025-06-02 16:31:53,835] Trial 65 finished with value: -3.529537615429742e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.010990438960244316, 'l2_leaf_reg': 5.164772535139013, 'random_strength': 3.9576247552879815, 'min_data_in_leaf': 58}. Best is trial 65 with value: -3.529537615429742e-08.
# [I 2025-06-02 16:32:06,790] Trial 66 finished with value: -3.5341570228620434e-08 and parameters: {'iterations': 200, 'depth': 9, 'learning_rate': 0.010975865583014343, 'l2_leaf_reg': 4.984348983179252, 'random_strength': 4.034800713886201, 'min_data_in_leaf': 57}. Best is trial 65 with value: -3.529537615429742e-08.
# [I 2025-06-02 16:32:14,143] Trial 67 finished with value: -3.530803617299518e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.014870179683587826, 'l2_leaf_reg': 6.503928154492975, 'random_strength': 4.409017062492168, 'min_data_in_leaf': 76}. Best is trial 65 with value: -3.529537615429742e-08.
# [I 2025-06-02 16:32:27,757] Trial 68 finished with value: -3.533870433909858e-08 and parameters: {'iterations': 200, 'depth': 9, 'learning_rate': 0.01096957257411812, 'l2_leaf_reg': 3.0880862905698536, 'random_strength': 3.7672702795463056, 'min_data_in_leaf': 69}. Best is trial 65 with value: -3.529537615429742e-08.
# [I 2025-06-02 16:32:34,856] Trial 69 finished with value: -3.529556319324221e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.0111769661215251, 'l2_leaf_reg': 4.071141109719663, 'random_strength': 3.9321895650958414, 'min_data_in_leaf': 51}. Best is trial 65 with value: -3.529537615429742e-08.
# [I 2025-06-02 16:32:41,607] Trial 70 finished with value: -3.52948595116404e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.011107476931722381, 'l2_leaf_reg': 4.200959268144969, 'random_strength': 4.099215803268483, 'min_data_in_leaf': 61}. Best is trial 70 with value: -3.52948595116404e-08.
# [I 2025-06-02 16:32:48,556] Trial 71 finished with value: -3.529731303718792e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.011146919079698107, 'l2_leaf_reg': 5.278775728620311, 'random_strength': 4.085115830631485, 'min_data_in_leaf': 52}. Best is trial 70 with value: -3.52948595116404e-08.
# [I 2025-06-02 16:32:55,568] Trial 72 finished with value: -3.529126644330237e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.011202482155235264, 'l2_leaf_reg': 5.34284483784283, 'random_strength': 4.562990088889025, 'min_data_in_leaf': 51}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:33:02,464] Trial 73 finished with value: -3.5292919206361076e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.01143312431646349, 'l2_leaf_reg': 5.378743517560252, 'random_strength': 4.851156197171734, 'min_data_in_leaf': 51}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:33:09,910] Trial 74 finished with value: -3.529273614315448e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.010133815386865246, 'l2_leaf_reg': 5.464071905626319, 'random_strength': 4.892594671628314, 'min_data_in_leaf': 52}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:33:22,152] Trial 75 finished with value: -3.534751915342087e-08 and parameters: {'iterations': 200, 'depth': 8, 'learning_rate': 0.015139958167733477, 'l2_leaf_reg': 5.617703419056463, 'random_strength': 4.7723508679160975, 'min_data_in_leaf': 61}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:33:35,683] Trial 76 finished with value: -3.532990861285456e-08 and parameters: {'iterations': 200, 'depth': 9, 'learning_rate': 0.01003031230774555, 'l2_leaf_reg': 6.4674284777974655, 'random_strength': 4.986383609797979, 'min_data_in_leaf': 51}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:33:42,792] Trial 77 finished with value: -3.530062914258131e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.01402501949704035, 'l2_leaf_reg': 6.129265987174186, 'random_strength': 4.628915624295842, 'min_data_in_leaf': 54}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:33:48,892] Trial 78 finished with value: -3.547577202492459e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.05872315704070593, 'l2_leaf_reg': 5.844856264285339, 'random_strength': 4.5453875431898805, 'min_data_in_leaf': 66}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:34:33,037] Trial 79 finished with value: -3.5463367111172736e-08 and parameters: {'iterations': 300, 'depth': 10, 'learning_rate': 0.012410973425225874, 'l2_leaf_reg': 5.0962305424925, 'random_strength': 4.802487186440509, 'min_data_in_leaf': 56}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:35:26,455] Trial 80 finished with value: -5.411711840068127e-08 and parameters: {'iterations': 800, 'depth': 9, 'learning_rate': 0.21303191054169154, 'l2_leaf_reg': 5.3459851202343645, 'random_strength': 4.2131555133112695, 'min_data_in_leaf': 45}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:35:34,786] Trial 81 finished with value: -3.5294063739885425e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.010970794153645519, 'l2_leaf_reg': 5.313144948423089, 'random_strength': 4.461613656962294, 'min_data_in_leaf': 52}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:35:43,084] Trial 82 finished with value: -3.5291669202442495e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.010880369430302819, 'l2_leaf_reg': 4.7957367253360585, 'random_strength': 4.538459464601834, 'min_data_in_leaf': 55}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:35:51,634] Trial 83 finished with value: -3.5296760126522e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.01061283542675736, 'l2_leaf_reg': 6.278315484873668, 'random_strength': 4.481687684629451, 'min_data_in_leaf': 55}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:36:05,078] Trial 84 finished with value: -3.535291880192688e-08 and parameters: {'iterations': 200, 'depth': 9, 'learning_rate': 0.012504506541528336, 'l2_leaf_reg': 4.756804236069904, 'random_strength': 4.666665338028187, 'min_data_in_leaf': 50}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:36:11,958] Trial 85 finished with value: -3.5292811672926006e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.010017059693323135, 'l2_leaf_reg': 5.432578568763447, 'random_strength': 4.848737386041938, 'min_data_in_leaf': 54}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:36:17,469] Trial 86 finished with value: -3.529644793052668e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.01658697339540906, 'l2_leaf_reg': 5.427612785559244, 'random_strength': 4.994315611956414, 'min_data_in_leaf': 55}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:36:32,083] Trial 87 finished with value: -3.5316390406917144e-08 and parameters: {'iterations': 100, 'depth': 10, 'learning_rate': 0.013771835758246255, 'l2_leaf_reg': 5.014075742037306, 'random_strength': 4.870346298398046, 'min_data_in_leaf': 62}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:36:39,086] Trial 88 finished with value: -3.5295669577152154e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.01182311549516615, 'l2_leaf_reg': 5.682178864051281, 'random_strength': 4.288313169295511, 'min_data_in_leaf': 52}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:36:51,886] Trial 89 finished with value: -3.532893733593662e-08 and parameters: {'iterations': 200, 'depth': 9, 'learning_rate': 0.01010823521494357, 'l2_leaf_reg': 6.6843017199023125, 'random_strength': 4.503169104099521, 'min_data_in_leaf': 46}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:37:02,611] Trial 90 finished with value: -3.5341489203895474e-08 and parameters: {'iterations': 200, 'depth': 8, 'learning_rate': 0.012723817187536133, 'l2_leaf_reg': 6.004016031813365, 'random_strength': 4.721724184197252, 'min_data_in_leaf': 50}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:37:09,388] Trial 91 finished with value: -3.529372229520329e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.011696354551964142, 'l2_leaf_reg': 5.684294013540989, 'random_strength': 4.414704222976419, 'min_data_in_leaf': 53}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:37:16,234] Trial 92 finished with value: -3.529377245088118e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.011326941662109525, 'l2_leaf_reg': 5.182967597877109, 'random_strength': 4.375546346856765, 'min_data_in_leaf': 60}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:37:30,752] Trial 93 finished with value: -3.532909063409142e-08 and parameters: {'iterations': 100, 'depth': 10, 'learning_rate': 0.014072031936885974, 'l2_leaf_reg': 5.23621175958467, 'random_strength': 4.421492711923308, 'min_data_in_leaf': 61}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:37:37,515] Trial 94 finished with value: -3.529691767843489e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.012216504276871033, 'l2_leaf_reg': 4.874680997015724, 'random_strength': 4.177403206661764, 'min_data_in_leaf': 54}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:37:44,216] Trial 95 finished with value: -3.532194378248926e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.015532828861335599, 'l2_leaf_reg': 5.847915374169618, 'random_strength': 4.607962460100794, 'min_data_in_leaf': 64}. Best is trial 72 with value: -3.529126644330237e-08.
# [I 2025-06-02 16:37:51,104] Trial 96 finished with value: -3.529114230855961e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.010810335797526601, 'l2_leaf_reg': 5.453446271580389, 'random_strength': 4.853361221814109, 'min_data_in_leaf': 58}. Best is trial 96 with value: -3.529114230855961e-08.
# [I 2025-06-02 16:38:01,600] Trial 97 finished with value: -3.5434630365646846e-08 and parameters: {'iterations': 200, 'depth': 8, 'learning_rate': 0.018236383767868247, 'l2_leaf_reg': 5.489904843524634, 'random_strength': 4.820243176997396, 'min_data_in_leaf': 70}. Best is trial 96 with value: -3.529114230855961e-08.
# [I 2025-06-02 16:38:08,414] Trial 98 finished with value: -3.5297961726116784e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.013131306799431731, 'l2_leaf_reg': 4.560048185354638, 'random_strength': 4.920786576592484, 'min_data_in_leaf': 60}. Best is trial 96 with value: -3.529114230855961e-08.
# [I 2025-06-02 16:40:29,933] Trial 99 finished with value: -3.5933949858805954e-08 and parameters: {'iterations': 1000, 'depth': 10, 'learning_rate': 0.011791560069099814, 'l2_leaf_reg': 7.087325189149254, 'random_strength': 4.674378182602967, 'min_data_in_leaf': 53}. Best is trial 96 with value: -3.529114230855961e-08.
# [I 2025-06-02 16:40:42,818] Trial 100 finished with value: -3.533027347994421e-08 and parameters: {'iterations': 200, 'depth': 9, 'learning_rate': 0.010087340278381571, 'l2_leaf_reg': 6.201045778158082, 'random_strength': 4.338883356300212, 'min_data_in_leaf': 56}. Best is trial 96 with value: -3.529114230855961e-08.
# [I 2025-06-02 16:40:49,527] Trial 101 finished with value: -3.529154619954942e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.011241216912963719, 'l2_leaf_reg': 5.616975825165303, 'random_strength': 4.569236183415609, 'min_data_in_leaf': 58}. Best is trial 96 with value: -3.529114230855961e-08.
# [I 2025-06-02 16:40:57,611] Trial 102 finished with value: -3.529132670887085e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.010770283614283324, 'l2_leaf_reg': 5.561777076982556, 'random_strength': 4.538990525672716, 'min_data_in_leaf': 58}. Best is trial 96 with value: -3.529114230855961e-08.
# [I 2025-06-02 16:41:04,499] Trial 103 finished with value: -3.5294751150456056e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.012216199901725105, 'l2_leaf_reg': 5.626108821861121, 'random_strength': 4.569379528818193, 'min_data_in_leaf': 58}. Best is trial 96 with value: -3.529114230855961e-08.
# [I 2025-06-02 16:41:11,254] Trial 104 finished with value: -3.5301205672447495e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.013442472902092174, 'l2_leaf_reg': 5.923100542445992, 'random_strength': 4.765185855577282, 'min_data_in_leaf': 55}. Best is trial 96 with value: -3.529114230855961e-08.
# [I 2025-06-02 16:41:17,941] Trial 105 finished with value: -3.5292452803942066e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.010616812202764652, 'l2_leaf_reg': 5.397532499992568, 'random_strength': 4.443952534120642, 'min_data_in_leaf': 49}. Best is trial 96 with value: -3.529114230855961e-08.
# [I 2025-06-02 16:41:48,768] Trial 106 finished with value: -3.560036963569356e-08 and parameters: {'iterations': 500, 'depth': 9, 'learning_rate': 0.0145196568822038, 'l2_leaf_reg': 5.463380942576606, 'random_strength': 4.901372202212008, 'min_data_in_leaf': 49}. Best is trial 96 with value: -3.529114230855961e-08.
# [I 2025-06-02 16:41:55,375] Trial 107 finished with value: -3.57580305844715e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.07536891877616751, 'l2_leaf_reg': 5.7480152557385935, 'random_strength': 4.685789950802039, 'min_data_in_leaf': 47}. Best is trial 96 with value: -3.529114230855961e-08.
# [I 2025-06-02 16:42:23,719] Trial 108 finished with value: -3.5365573800996376e-08 and parameters: {'iterations': 200, 'depth': 10, 'learning_rate': 0.010592401823520819, 'l2_leaf_reg': 4.724645203032629, 'random_strength': 4.36145267439996, 'min_data_in_leaf': 40}. Best is trial 96 with value: -3.529114230855961e-08.
# [I 2025-06-02 16:42:29,778] Trial 109 finished with value: -3.52886325261335e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.011744499857867014, 'l2_leaf_reg': 5.01378470694359, 'random_strength': 4.855443012230149, 'min_data_in_leaf': 57}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:42:40,625] Trial 110 finished with value: -3.532937941283198e-08 and parameters: {'iterations': 200, 'depth': 8, 'learning_rate': 0.012925600459086155, 'l2_leaf_reg': 5.017051197625284, 'random_strength': 4.8535905889419, 'min_data_in_leaf': 57}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:42:47,665] Trial 111 finished with value: -3.529240753624143e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.011959152561577816, 'l2_leaf_reg': 5.136908196497653, 'random_strength': 4.933171053644326, 'min_data_in_leaf': 63}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:42:54,368] Trial 112 finished with value: -3.5297978663570636e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.01188581240463259, 'l2_leaf_reg': 5.57615401158005, 'random_strength': 4.942452661972454, 'min_data_in_leaf': 64}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:43:01,150] Trial 113 finished with value: -3.529438184685599e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.010036458162288799, 'l2_leaf_reg': 6.06458504578331, 'random_strength': 4.742651648318115, 'min_data_in_leaf': 54}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:43:07,885] Trial 114 finished with value: -3.5295621064353866e-08 and parameters: {'iterations': 100, 'depth': 9, 'learning_rate': 0.010643755141040873, 'l2_leaf_reg': 4.814929723290807, 'random_strength': 4.604014074908436, 'min_data_in_leaf': 50}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:43:13,719] Trial 115 finished with value: -3.528972084513522e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.011722477470861897, 'l2_leaf_reg': 5.367060234411795, 'random_strength': 4.531932614998059, 'min_data_in_leaf': 67}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:43:19,439] Trial 116 finished with value: -3.537105074407872e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.030201394360217293, 'l2_leaf_reg': 5.434481392743645, 'random_strength': 4.542565163207027, 'min_data_in_leaf': 68}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:43:30,308] Trial 117 finished with value: -3.5323526757726254e-08 and parameters: {'iterations': 200, 'depth': 8, 'learning_rate': 0.012708367639390683, 'l2_leaf_reg': 4.485172069973534, 'random_strength': 4.84495275571245, 'min_data_in_leaf': 65}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:43:35,913] Trial 118 finished with value: -3.529094261162092e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.01395519149487716, 'l2_leaf_reg': 4.894806558063263, 'random_strength': 4.723785347512199, 'min_data_in_leaf': 73}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:43:41,462] Trial 119 finished with value: -3.529285725656976e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.015171940019800113, 'l2_leaf_reg': 5.012908605418593, 'random_strength': 4.994609259070083, 'min_data_in_leaf': 77}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:43:52,141] Trial 120 finished with value: -3.533316390463241e-08 and parameters: {'iterations': 200, 'depth': 8, 'learning_rate': 0.013280969802795098, 'l2_leaf_reg': 4.720323239799683, 'random_strength': 4.7287920213253285, 'min_data_in_leaf': 79}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:43:57,809] Trial 121 finished with value: -3.5292847073329275e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.015168986939814602, 'l2_leaf_reg': 4.971977467861253, 'random_strength': 4.994962632375528, 'min_data_in_leaf': 77}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:44:03,898] Trial 122 finished with value: -3.529211602647681e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.01378946109142751, 'l2_leaf_reg': 5.132715427037882, 'random_strength': 4.636606634591617, 'min_data_in_leaf': 83}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:44:09,876] Trial 123 finished with value: -3.529422422960535e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.014077902836025709, 'l2_leaf_reg': 5.1303752118939085, 'random_strength': 4.59466244908879, 'min_data_in_leaf': 93}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:44:15,565] Trial 124 finished with value: -3.5291051087483457e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.010000850703720875, 'l2_leaf_reg': 4.375008283989244, 'random_strength': 4.503914198472976, 'min_data_in_leaf': 66}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:44:21,422] Trial 125 finished with value: -3.529689390346428e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.010819618865660349, 'l2_leaf_reg': 4.4534672226294685, 'random_strength': 4.2591197408437935, 'min_data_in_leaf': 84}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:44:27,050] Trial 126 finished with value: -3.529185280196815e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.012222442054966347, 'l2_leaf_reg': 4.3494032714845, 'random_strength': 4.4981152111892, 'min_data_in_leaf': 86}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:44:32,805] Trial 127 finished with value: -3.529263271477594e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.012340416130366209, 'l2_leaf_reg': 4.639422867363555, 'random_strength': 4.495115376821831, 'min_data_in_leaf': 89}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:44:38,312] Trial 128 finished with value: -3.5306120446022024e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.01725467775804011, 'l2_leaf_reg': 4.403224752464316, 'random_strength': 4.667477368718134, 'min_data_in_leaf': 83}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:44:47,896] Trial 129 finished with value: -3.533845102726409e-08 and parameters: {'iterations': 200, 'depth': 7, 'learning_rate': 0.014029660221749438, 'l2_leaf_reg': 4.873322376393727, 'random_strength': 4.504151189851608, 'min_data_in_leaf': 91}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:44:53,672] Trial 130 finished with value: -3.541343625758403e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.04401734959907159, 'l2_leaf_reg': 4.334393329335842, 'random_strength': 4.328406814666248, 'min_data_in_leaf': 73}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:44:59,585] Trial 131 finished with value: -3.529459675209939e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.01214395249431443, 'l2_leaf_reg': 5.2194833345810006, 'random_strength': 4.4837983600994376, 'min_data_in_leaf': 97}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:45:05,271] Trial 132 finished with value: -3.529443569324674e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.012674397888998752, 'l2_leaf_reg': 4.652944450953724, 'random_strength': 4.5574468734589075, 'min_data_in_leaf': 86}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:45:11,123] Trial 133 finished with value: -3.5295886628620457e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.011119140579857498, 'l2_leaf_reg': 4.741598833971338, 'random_strength': 4.199687558757377, 'min_data_in_leaf': 89}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:45:16,760] Trial 134 finished with value: -3.529190307970577e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.011755982759405722, 'l2_leaf_reg': 5.204450730696733, 'random_strength': 4.731402431113979, 'min_data_in_leaf': 71}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:45:22,652] Trial 135 finished with value: -3.5289933419827634e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.011633091306406574, 'l2_leaf_reg': 5.277604526973946, 'random_strength': 4.751044337121236, 'min_data_in_leaf': 72}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:45:28,220] Trial 136 finished with value: -3.5289679369358875e-08 and parameters: {'iterations': 100, 'depth': 8, 'learning_rate': 0.011595301582957743, 'l2_leaf_reg': 5.129471803151848, 'random_strength': 4.767319332904789, 'min_data_in_leaf': 72}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:46:07,826] Trial 137 finished with value: -3.578081794486723e-08 and parameters: {'iterations': 800, 'depth': 8, 'learning_rate': 0.013654026118783805, 'l2_leaf_reg': 3.9897727819409807, 'random_strength': 4.768439824827283, 'min_data_in_leaf': 72}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:46:13,096] Trial 138 finished with value: -3.529765744112271e-08 and parameters: {'iterations': 100, 'depth': 7, 'learning_rate': 0.01138175689355969, 'l2_leaf_reg': 4.9298318572536335, 'random_strength': 4.687012003082095, 'min_data_in_leaf': 70}. Best is trial 109 with value: -3.52886325261335e-08.
# [I 2025-06-02 16:46:23,704] Trial 139 finished with value: -3.5337061992419215e-08 and parameters: {'iterations': 200, 'depth': 8, 'learning_rate': 0.012968418093999012, 'l2_leaf_reg': 5.247439479898515, 'random_strength': 4.618119258640794, 'min_data_in_leaf': 75}. Best is trial 109 with value: -3.52886325261335e-08.
# 🔍 Checking variance in OOF base model predictions Catboost model:
#             model_0
# count  6.408590e+05
# mean  -2.128387e-07
# std    6.871202e-06
# min   -6.958839e-05
# 25%   -1.804126e-06
# 50%    0.000000e+00
# 75%    3.053930e-06
# max    6.811051e-05
# Std per model:
#  model_0    0.000007
# dtype: float64
#
# Evaluation CatBoost
#
# 📊 CatBoostRegressor Performance:
# Train MSE: 0.00000006
# Test MSE: 0.00000000
# Overfit ratio (Test / Train): 0.03
# ⚠️ Possibly underfitting.
#
# 🔍 Target distribution Seq:
# count    640859.000000
# mean          0.000002
# std           0.000250
# min          -0.001129
# 25%          -0.000074
# 50%           0.000002
# 75%           0.000080
# max           0.001068
# Name: reg_target_lookahead12, dtype: float64
#
# 🔍 Checking prediction variance from Catboost:
# Min: -0.00000621
# Max: 0.00000744
# Mean: 0.00000104
# Std Dev: 0.00000182
# First 5 Predictions: [-1.90954973e-07  4.46469636e-07  4.46469636e-07  5.35601907e-07
#   4.05746054e-07]
# MAE: 0.0000
# RMSE: 0.0000
# R²: -0.0008

# %% [markdown]
# # Test

# %%
all_results = []
thresholds = [0.000004]
lookahead = LOOK_AHEAD

for result in reg_results:
    lookahead = result['lookahead']
    preds_stack = result['preds_catboost']
    X_test_combined = result['X_test_tree']
    y_test = result['true_values']
    labeled = pd.read_parquet(f"parquet/labeled_data_L{lookahead}_PT2SL1VB{lookahead}{market}.parquet")
    df_backtest = labeled.copy()

    print(f"\n🔎 Predicted return range for LOOKAHEAD=12: STACK: min={preds_stack.min():.8f}, max={preds_stack.max():.8f}")
    for params in combinations:
        for thresh in thresholds:
            results = evaluate_regression(
                X_test=X_test_combined,
                preds_stack=preds_stack,
                labeled=labeled,
                df=df_backtest,
                avoid_funcs=avoid_funcs,
                SL_ATR_MULT=params['SL_ATR_MULT'],
                TP_ATR_MULT=params['TP_ATR_MULT'],
                TRAIL_START_MULT=params['TRAIL_START_MULT'],
                TRAIL_STOP_MULT=params['TRAIL_STOP_MULT'],
                TICK_VALUE=1,
                is_same_session=None,
                long_thresh=thresh,
                short_thresh=-thresh,
                base_contracts=1,
                max_contracts=1,
                skip_weak_conf=False,
                weak_conf_zscore=0.2
            )

            results['params'] = params
            results['threshold'] = thresh
            all_results.append(results)

            print(f"\n\n🔍 Evaluating with params: {params}")

            print(
                f"\n✅ LOOKAHEAD={lookahead} | Threshold={thresh}"
                f"\nPnL: ${results['pnl']:.2f}"
                f"\nTrades: {results['trades']}"
                f"\nWin Rate: {results['win_rate']:.2%}"
                f"\nExpectancy: {results['expectancy']:.2f}"
                f"\nProfit Factor: {results['profit_factor']:.2f}"
                f"\nAverage Confidence Win: {results['avg_confidence_win']:.7f}"
                f"\nAverage Confidence Loss: {results['avg_confidence_loss']:.7f}"
                f"\nSharpe Ratio: {results['sharpe']:.2f}"
                f"\nLong Trades: {results['long_trades']} | Short Trades: {results['short_trades']}"
            )

            print("Avoid Hits:")
            for name, count in results['avoid_hits'].items():
                print(f" - {name}: {count}")

            if not results['results'].empty and 'pnl' in results['results'].columns:
                print("\n🔢 Top 5 PnL trades:")
                print(results['results'].sort_values(by='pnl', ascending=False).head(5))

                print("\n🔻 Bottom 5 PnL trades:")
                print(results['results'].sort_values(by='pnl', ascending=True).head(5))
            else:
                print("\n⚠️ No trades executed, skipping PnL trade breakdown.")


summary_df = pd.DataFrame([{
    'pnl': r['pnl'],
    'sharpe': r['sharpe'],
    'expectancy': r['expectancy'],
    'profit_factor': r['profit_factor'],
    'win_rate': r['win_rate'],
    'trades': r['trades'],
    'avg_confidence_win': r['avg_confidence_win'],
    'avg_confidence_loss': r['avg_confidence_loss'],
    'results': r['results'],
    **r['params']
} for r in all_results])
top = summary_df.sort_values(by='sharpe', ascending=False).head(10)
print("\n🏁 Top 10 Configurations Across All Lookaheads:")
print(top[['pnl', 'sharpe', 'expectancy', 'profit_factor', 'win_rate', 'trades', 'avg_confidence_win', 'avg_confidence_loss']])
# Out:
# 🔎 Predicted return range for LOOKAHEAD=12: STACK: min=-0.00000621, max=0.00000744
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 2.0, 'TRAIL_START_MULT': 0.5, 'TRAIL_STOP_MULT': 0.5, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $-10505.64
# Trades: 2162
# Win Rate: 36.26%
# Expectancy: -4.86
# Profit Factor: 0.89
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: -1.93
# Long Trades: 1704 | Short Trades: 458
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time   side  entry_price  \
# 1695 2025-01-20 08:05:00-05:00 2025-01-20 08:25:00-05:00   long    106839.76
# 1494 2024-12-05 00:40:00-05:00 2024-12-05 00:55:00-05:00   long    102050.01
# 1534 2024-12-12 10:55:00-05:00 2024-12-12 11:15:00-05:00   long    101973.66
# 1568 2024-12-19 17:55:00-05:00 2024-12-19 18:20:00-05:00  short     98204.58
# 1464 2024-11-20 22:45:00-05:00 2024-11-21 00:00:00-05:00   long     96852.00
#
#          exit_price         pnl     mfe   mae   gross_pnl  vol_adj_pred  \
# 1695  107373.958800  530.218800  620.14  3.09  534.198800      0.000004
# 1494  102560.260050  506.270050  573.99  0.00  510.250050      0.000004
# 1534  102483.528300  505.888300  526.34  0.00  509.868300      0.000005
# 1568   97713.557100  487.042900  582.25  0.00  491.022900     -0.000005
# 1464   97330.100246  474.120246  810.36  0.00  478.100246      0.000005
#
#       confidence  position_size
# 1695    1.764030            1.0
# 1494    1.814888            1.0
# 1534    1.988325            1.0
# 1568    2.000000            1.0
# 1464    2.000000            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 262  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 263  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1920 2025-04-02 16:35:00-04:00 2025-04-02 17:05:00-04:00  long     85569.05
# 1422 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 260  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price         pnl     mfe      mae   gross_pnl  vol_adj_pred  \
# 262   60930.764240 -407.405760    0.00   876.78 -403.425760      0.000004
# 263   60191.718160 -389.661840    0.00  1377.40 -385.681840      0.000005
# 1920  85264.444486 -308.585514  286.95   506.24 -304.605514      0.000004
# 1422  90054.234874 -305.715126    0.00  1063.97 -301.735126      0.000005
# 260   61041.555617 -296.094383    0.00  2633.67 -292.114383      0.000004
#
#       confidence  position_size
# 262     1.733479            1.0
# 263     1.972732            1.0
# 1920    1.697174            1.0
# 1422    2.000000            1.0
# 260     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 2.0, 'TRAIL_START_MULT': 0.5, 'TRAIL_STOP_MULT': 1.0, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $7760.80
# Trades: 1941
# Win Rate: 28.13%
# Expectancy: 4.00
# Profit Factor: 1.07
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 1.18
# Long Trades: 1529 | Short Trades: 412
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1513 2025-01-20 07:40:00-05:00 2025-01-20 08:25:00-05:00  long    106816.01
# 1516 2025-01-21 16:20:00-05:00 2025-01-21 17:00:00-05:00  long    106249.11
# 1907 2025-05-21 13:50:00-04:00 2025-05-21 14:10:00-04:00  long    106232.34
# 1484 2025-01-17 12:55:00-05:00 2025-01-17 13:20:00-05:00  long    104083.98
# 1869 2025-05-09 05:35:00-04:00 2025-05-09 06:45:00-04:00  long    102739.09
#
#         exit_price        pnl     mfe     mae  gross_pnl  vol_adj_pred  \
# 1513  107350.09005  530.10005  643.89  164.90  534.08005      0.000004
# 1516  106780.35555  527.26555  565.26   29.11  531.24555      0.000004
# 1907  106763.50170  527.18170  858.57    0.00  531.16170      0.000005
# 1484  104604.39990  516.43990  588.96    0.00  520.41990      0.000005
# 1869  103252.78545  509.71545  596.91  139.11  513.69545      0.000004
#
#       confidence  position_size
# 1513    1.814035            1.0
# 1516    1.705929            1.0
# 1907    1.973684            1.0
# 1484    2.000000            1.0
# 1869    1.825034            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 235  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 236  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1720 2025-04-02 16:35:00-04:00 2025-04-02 17:05:00-04:00  long     85569.05
# 1267 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 233  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price         pnl     mfe      mae   gross_pnl  vol_adj_pred  \
# 235   60930.764240 -407.405760    0.00   876.78 -403.425760      0.000004
# 236   60191.718160 -389.661840    0.00  1377.40 -385.681840      0.000005
# 1720  85264.444486 -308.585514  286.95   506.24 -304.605514      0.000004
# 1267  90054.234874 -305.715126    0.00  1063.97 -301.735126      0.000005
# 233   61041.555617 -296.094383    0.00  2633.67 -292.114383      0.000004
#
#       confidence  position_size
# 235     1.733479            1.0
# 236     1.972732            1.0
# 1720    1.697174            1.0
# 1267    2.000000            1.0
# 233     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 2.0, 'TRAIL_START_MULT': 0.5, 'TRAIL_STOP_MULT': 0.3, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $1640.18
# Trades: 2242
# Win Rate: 40.72%
# Expectancy: 0.73
# Profit Factor: 1.02
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 0.30
# Long Trades: 1770 | Short Trades: 472
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time   side  entry_price  \
# 1764 2025-01-20 08:15:00-05:00 2025-01-20 08:35:00-05:00   long    107027.19
# 1548 2024-12-05 00:40:00-05:00 2024-12-05 00:55:00-05:00   long    102050.01
# 1628 2024-12-19 17:55:00-05:00 2024-12-19 18:20:00-05:00  short     98204.58
# 1632 2024-12-20 14:30:00-05:00 2024-12-20 14:45:00-05:00  short     97712.02
# 1526 2024-11-21 09:35:00-05:00 2024-11-21 09:50:00-05:00   long     96748.29
#
#         exit_price        pnl     mfe  mae  gross_pnl  vol_adj_pred  \
# 1764  107562.32595  531.15595  872.81  0.0  535.13595      0.000004
# 1548  102560.26005  506.27005  573.99  0.0  510.25005      0.000004
# 1628   97713.55710  487.04290  582.25  0.0  491.02290     -0.000005
# 1632   97223.45990  484.58010  496.26  0.0  488.56010     -0.000005
# 1526   97232.03145  479.76145  933.14  0.0  483.74145      0.000004
#
#       confidence  position_size
# 1764    1.682931            1.0
# 1548    1.814888            1.0
# 1628    2.000000            1.0
# 1632    2.000000            1.0
# 1526    1.762898            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 270  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 271  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1991 2025-04-02 16:35:00-04:00 2025-04-02 17:05:00-04:00  long     85569.05
# 1472 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 268  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price         pnl     mfe      mae   gross_pnl  vol_adj_pred  \
# 270   60930.764240 -407.405760    0.00   876.78 -403.425760      0.000004
# 271   60191.718160 -389.661840    0.00  1377.40 -385.681840      0.000005
# 1991  85264.444486 -308.585514  286.95   506.24 -304.605514      0.000004
# 1472  90054.234874 -305.715126    0.00  1063.97 -301.735126      0.000005
# 268   61041.555617 -296.094383    0.00  2633.67 -292.114383      0.000004
#
#       confidence  position_size
# 270     1.733479            1.0
# 271     1.972732            1.0
# 1991    1.697174            1.0
# 1472    2.000000            1.0
# 268     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 2.0, 'TRAIL_START_MULT': 1.0, 'TRAIL_STOP_MULT': 0.5, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $4335.33
# Trades: 2078
# Win Rate: 35.90%
# Expectancy: 2.09
# Profit Factor: 1.04
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 0.74
# Long Trades: 1638 | Short Trades: 440
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time   side  entry_price  \
# 1628 2025-01-20 07:40:00-05:00 2025-01-20 08:25:00-05:00   long    106816.01
# 2041 2025-05-21 13:50:00-04:00 2025-05-21 14:10:00-04:00   long    106232.34
# 1430 2024-12-05 00:40:00-05:00 2024-12-05 00:55:00-05:00   long    102050.01
# 1471 2024-12-12 10:55:00-05:00 2024-12-12 11:15:00-05:00   long    101973.66
# 1504 2024-12-19 17:55:00-05:00 2024-12-19 18:20:00-05:00  short     98204.58
#
#         exit_price        pnl     mfe    mae  gross_pnl  vol_adj_pred  \
# 1628  107350.09005  530.10005  643.89  164.9  534.08005      0.000004
# 2041  106763.50170  527.18170  858.57    0.0  531.16170      0.000005
# 1430  102560.26005  506.27005  573.99    0.0  510.25005      0.000004
# 1471  102483.52830  505.88830  526.34    0.0  509.86830      0.000005
# 1504   97713.55710  487.04290  582.25    0.0  491.02290     -0.000005
#
#       confidence  position_size
# 1628    1.814035            1.0
# 2041    1.973684            1.0
# 1430    1.814888            1.0
# 1471    1.988325            1.0
# 1504    2.000000            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 252  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 253  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1845 2025-04-02 16:35:00-04:00 2025-04-02 17:05:00-04:00  long     85569.05
# 1362 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 250  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price         pnl     mfe      mae   gross_pnl  vol_adj_pred  \
# 252   60930.764240 -407.405760    0.00   876.78 -403.425760      0.000004
# 253   60191.718160 -389.661840    0.00  1377.40 -385.681840      0.000005
# 1845  85264.444486 -308.585514  286.95   506.24 -304.605514      0.000004
# 1362  90054.234874 -305.715126    0.00  1063.97 -301.735126      0.000005
# 250   61041.555617 -296.094383    0.00  2633.67 -292.114383      0.000004
#
#       confidence  position_size
# 252     1.733479            1.0
# 253     1.972732            1.0
# 1845    1.697174            1.0
# 1362    2.000000            1.0
# 250     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 2.0, 'TRAIL_START_MULT': 1.0, 'TRAIL_STOP_MULT': 1.0, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $8196.97
# Trades: 1937
# Win Rate: 28.34%
# Expectancy: 4.23
# Profit Factor: 1.08
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 1.25
# Long Trades: 1529 | Short Trades: 408
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1505 2025-01-20 07:40:00-05:00 2025-01-20 08:25:00-05:00  long    106816.01
# 1902 2025-05-21 13:50:00-04:00 2025-05-21 14:10:00-04:00  long    106232.34
# 1508 2025-01-21 16:15:00-05:00 2025-01-21 16:35:00-05:00  long    105897.15
# 1476 2025-01-17 12:55:00-05:00 2025-01-17 13:20:00-05:00  long    104083.98
# 1864 2025-05-09 05:35:00-04:00 2025-05-09 06:45:00-04:00  long    102739.09
#
#         exit_price        pnl     mfe     mae  gross_pnl  vol_adj_pred  \
# 1505  107350.09005  530.10005  643.89  164.90  534.08005      0.000004
# 1902  106763.50170  527.18170  858.57    0.00  531.16170      0.000005
# 1508  106426.63575  525.50575  654.57    0.00  529.48575      0.000005
# 1476  104604.39990  516.43990  588.96    0.00  520.41990      0.000005
# 1864  103252.78545  509.71545  596.91  139.11  513.69545      0.000004
#
#       confidence  position_size
# 1505    1.814035            1.0
# 1902    1.973684            1.0
# 1508    2.000000            1.0
# 1476    2.000000            1.0
# 1864    1.825034            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 231  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 232  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1713 2025-04-02 16:35:00-04:00 2025-04-02 17:05:00-04:00  long     85569.05
# 1262 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 229  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price         pnl     mfe      mae   gross_pnl  vol_adj_pred  \
# 231   60930.764240 -407.405760    0.00   876.78 -403.425760      0.000004
# 232   60191.718160 -389.661840    0.00  1377.40 -385.681840      0.000005
# 1713  85264.444486 -308.585514  286.95   506.24 -304.605514      0.000004
# 1262  90054.234874 -305.715126    0.00  1063.97 -301.735126      0.000005
# 229   61041.555617 -296.094383    0.00  2633.67 -292.114383      0.000004
#
#       confidence  position_size
# 231     1.733479            1.0
# 232     1.972732            1.0
# 1713    1.697174            1.0
# 1262    2.000000            1.0
# 229     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 2.0, 'TRAIL_START_MULT': 1.0, 'TRAIL_STOP_MULT': 0.3, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $16360.11
# Trades: 2113
# Win Rate: 38.00%
# Expectancy: 7.74
# Profit Factor: 1.16
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 2.73
# Long Trades: 1668 | Short Trades: 445
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time   side  entry_price  \
# 1657 2025-01-20 07:40:00-05:00 2025-01-20 08:25:00-05:00   long    106816.01
# 2076 2025-05-21 13:50:00-04:00 2025-05-21 14:10:00-04:00   long    106232.34
# 1451 2024-12-05 00:40:00-05:00 2024-12-05 00:55:00-05:00   long    102050.01
# 1528 2024-12-19 17:55:00-05:00 2024-12-19 18:20:00-05:00  short     98204.58
# 1532 2024-12-20 14:30:00-05:00 2024-12-20 14:45:00-05:00  short     97712.02
#
#         exit_price        pnl     mfe    mae  gross_pnl  vol_adj_pred  \
# 1657  107350.09005  530.10005  643.89  164.9  534.08005      0.000004
# 2076  106763.50170  527.18170  858.57    0.0  531.16170      0.000005
# 1451  102560.26005  506.27005  573.99    0.0  510.25005      0.000004
# 1528   97713.55710  487.04290  582.25    0.0  491.02290     -0.000005
# 1532   97223.45990  484.58010  496.26    0.0  488.56010     -0.000005
#
#       confidence  position_size
# 1657    1.814035            1.0
# 2076    1.973684            1.0
# 1451    1.814888            1.0
# 1528    2.000000            1.0
# 1532    2.000000            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 255  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 256  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1875 2025-04-02 16:35:00-04:00 2025-04-02 17:05:00-04:00  long     85569.05
# 1378 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 253  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price         pnl     mfe      mae   gross_pnl  vol_adj_pred  \
# 255   60930.764240 -407.405760    0.00   876.78 -403.425760      0.000004
# 256   60191.718160 -389.661840    0.00  1377.40 -385.681840      0.000005
# 1875  85264.444486 -308.585514  286.95   506.24 -304.605514      0.000004
# 1378  90054.234874 -305.715126    0.00  1063.97 -301.735126      0.000005
# 253   61041.555617 -296.094383    0.00  2633.67 -292.114383      0.000004
#
#       confidence  position_size
# 255     1.733479            1.0
# 256     1.972732            1.0
# 1875    1.697174            1.0
# 1378    2.000000            1.0
# 253     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 2.0, 'TRAIL_START_MULT': 0.3, 'TRAIL_STOP_MULT': 0.5, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $-11868.59
# Trades: 2169
# Win Rate: 35.36%
# Expectancy: -5.47
# Profit Factor: 0.88
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: -2.19
# Long Trades: 1711 | Short Trades: 458
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time   side  entry_price  \
# 1700 2025-01-20 08:05:00-05:00 2025-01-20 08:25:00-05:00   long    106839.76
# 1503 2024-12-05 00:40:00-05:00 2024-12-05 00:55:00-05:00   long    102050.01
# 1542 2024-12-12 10:55:00-05:00 2024-12-12 11:15:00-05:00   long    101973.66
# 1576 2024-12-19 17:55:00-05:00 2024-12-19 18:20:00-05:00  short     98204.58
# 1472 2024-11-20 22:45:00-05:00 2024-11-21 00:00:00-05:00   long     96852.00
#
#          exit_price         pnl     mfe   mae   gross_pnl  vol_adj_pred  \
# 1700  107373.958800  530.218800  620.14  3.09  534.198800      0.000004
# 1503  102560.260050  506.270050  573.99  0.00  510.250050      0.000004
# 1542  102483.528300  505.888300  526.34  0.00  509.868300      0.000005
# 1576   97713.557100  487.042900  582.25  0.00  491.022900     -0.000005
# 1472   97330.100246  474.120246  810.36  0.00  478.100246      0.000005
#
#       confidence  position_size
# 1700    1.764030            1.0
# 1503    1.814888            1.0
# 1542    1.988325            1.0
# 1576    2.000000            1.0
# 1472    2.000000            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 265  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 266  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1430 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 263  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
# 294  2024-03-08 11:00:00-05:00 2024-03-08 11:15:00-05:00  long     66946.86
#
#         exit_price         pnl  mfe      mae   gross_pnl  vol_adj_pred  \
# 265   60930.764240 -407.405760  0.0   876.78 -403.425760      0.000004
# 266   60191.718160 -389.661840  0.0  1377.40 -385.681840      0.000005
# 1430  90054.234874 -305.715126  0.0  1063.97 -301.735126      0.000005
# 263   61041.555617 -296.094383  0.0  2633.67 -292.114383      0.000004
# 294   66662.468156 -288.371844  0.0   864.20 -284.391844      0.000004
#
#       confidence  position_size
# 265     1.733479            1.0
# 266     1.972732            1.0
# 1430    2.000000            1.0
# 263     1.689292            1.0
# 294     1.743972            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 2.0, 'TRAIL_START_MULT': 0.3, 'TRAIL_STOP_MULT': 1.0, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $7760.80
# Trades: 1941
# Win Rate: 28.13%
# Expectancy: 4.00
# Profit Factor: 1.07
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 1.18
# Long Trades: 1529 | Short Trades: 412
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1513 2025-01-20 07:40:00-05:00 2025-01-20 08:25:00-05:00  long    106816.01
# 1516 2025-01-21 16:20:00-05:00 2025-01-21 17:00:00-05:00  long    106249.11
# 1907 2025-05-21 13:50:00-04:00 2025-05-21 14:10:00-04:00  long    106232.34
# 1484 2025-01-17 12:55:00-05:00 2025-01-17 13:20:00-05:00  long    104083.98
# 1869 2025-05-09 05:35:00-04:00 2025-05-09 06:45:00-04:00  long    102739.09
#
#         exit_price        pnl     mfe     mae  gross_pnl  vol_adj_pred  \
# 1513  107350.09005  530.10005  643.89  164.90  534.08005      0.000004
# 1516  106780.35555  527.26555  565.26   29.11  531.24555      0.000004
# 1907  106763.50170  527.18170  858.57    0.00  531.16170      0.000005
# 1484  104604.39990  516.43990  588.96    0.00  520.41990      0.000005
# 1869  103252.78545  509.71545  596.91  139.11  513.69545      0.000004
#
#       confidence  position_size
# 1513    1.814035            1.0
# 1516    1.705929            1.0
# 1907    1.973684            1.0
# 1484    2.000000            1.0
# 1869    1.825034            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 235  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 236  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1720 2025-04-02 16:35:00-04:00 2025-04-02 17:05:00-04:00  long     85569.05
# 1267 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 233  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price         pnl     mfe      mae   gross_pnl  vol_adj_pred  \
# 235   60930.764240 -407.405760    0.00   876.78 -403.425760      0.000004
# 236   60191.718160 -389.661840    0.00  1377.40 -385.681840      0.000005
# 1720  85264.444486 -308.585514  286.95   506.24 -304.605514      0.000004
# 1267  90054.234874 -305.715126    0.00  1063.97 -301.735126      0.000005
# 233   61041.555617 -296.094383    0.00  2633.67 -292.114383      0.000004
#
#       confidence  position_size
# 235     1.733479            1.0
# 236     1.972732            1.0
# 1720    1.697174            1.0
# 1267    2.000000            1.0
# 233     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 2.0, 'TRAIL_START_MULT': 0.3, 'TRAIL_STOP_MULT': 0.3, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $281.22
# Trades: 2270
# Win Rate: 39.65%
# Expectancy: 0.12
# Profit Factor: 1.00
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 0.05
# Long Trades: 1792 | Short Trades: 478
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time   side  entry_price  \
# 1784 2025-01-20 08:15:00-05:00 2025-01-20 08:35:00-05:00   long    107027.19
# 1567 2024-12-05 00:40:00-05:00 2024-12-05 00:55:00-05:00   long    102050.01
# 1648 2024-12-19 17:55:00-05:00 2024-12-19 18:20:00-05:00  short     98204.58
# 1652 2024-12-20 14:30:00-05:00 2024-12-20 14:45:00-05:00  short     97712.02
# 1535 2024-11-20 22:45:00-05:00 2024-11-21 00:00:00-05:00   long     96852.00
#
#          exit_price         pnl     mfe  mae   gross_pnl  vol_adj_pred  \
# 1784  107562.325950  531.155950  872.81  0.0  535.135950      0.000004
# 1567  102560.260050  506.270050  573.99  0.0  510.250050      0.000004
# 1648   97713.557100  487.042900  582.25  0.0  491.022900     -0.000005
# 1652   97223.459900  484.580100  496.26  0.0  488.560100     -0.000005
# 1535   97330.100246  474.120246  810.36  0.0  478.100246      0.000005
#
#       confidence  position_size
# 1784    1.682931            1.0
# 1567    1.814888            1.0
# 1648    2.000000            1.0
# 1652    2.000000            1.0
# 1535    2.000000            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 274  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 275  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1490 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 272  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
# 305  2024-03-08 11:00:00-05:00 2024-03-08 11:15:00-05:00  long     66946.86
#
#         exit_price         pnl  mfe      mae   gross_pnl  vol_adj_pred  \
# 274   60930.764240 -407.405760  0.0   876.78 -403.425760      0.000004
# 275   60191.718160 -389.661840  0.0  1377.40 -385.681840      0.000005
# 1490  90054.234874 -305.715126  0.0  1063.97 -301.735126      0.000005
# 272   61041.555617 -296.094383  0.0  2633.67 -292.114383      0.000004
# 305   66662.468156 -288.371844  0.0   864.20 -284.391844      0.000004
#
#       confidence  position_size
# 274     1.733479            1.0
# 275     1.972732            1.0
# 1490    2.000000            1.0
# 272     1.689292            1.0
# 305     1.743972            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 4.0, 'TRAIL_START_MULT': 0.5, 'TRAIL_STOP_MULT': 0.5, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $-11776.56
# Trades: 2154
# Win Rate: 36.21%
# Expectancy: -5.47
# Profit Factor: 0.88
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: -2.15
# Long Trades: 1696 | Short Trades: 458
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1688 2025-01-20 08:05:00-05:00 2025-01-20 08:25:00-05:00  long    106839.76
# 2092 2025-05-12 02:55:00-04:00 2025-05-12 03:10:00-04:00  long    104997.91
# 1699 2025-01-24 09:30:00-05:00 2025-01-24 09:45:00-05:00  long    104936.44
# 2091 2025-05-11 20:55:00-04:00 2025-05-11 21:10:00-04:00  long    104551.28
# 2095 2025-05-13 10:10:00-04:00 2025-05-13 10:30:00-04:00  long    102889.54
#
#         exit_price        pnl      mfe   mae  gross_pnl  vol_adj_pred  \
# 1688  107373.95880  530.21880   620.14  3.09  534.19880      0.000004
# 2092  105522.89955  521.00955   762.09  0.00  524.98955      0.000005
# 1699  105461.12220  520.70220  1385.22  0.00  524.68220      0.000004
# 2091  105074.03640  518.77640   535.14  0.00  522.75640      0.000004
# 2095  103403.98770  510.46770   546.46  0.00  514.44770      0.000004
#
#       confidence  position_size
# 1688    1.764030            1.0
# 2092    1.957519            1.0
# 1699    1.647260            1.0
# 2091    1.697250            1.0
# 2095    1.730703            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 261  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 262  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1913 2025-04-02 16:35:00-04:00 2025-04-02 17:05:00-04:00  long     85569.05
# 1415 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 259  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price         pnl     mfe      mae   gross_pnl  vol_adj_pred  \
# 261   60930.764240 -407.405760    0.00   876.78 -403.425760      0.000004
# 262   60191.718160 -389.661840    0.00  1377.40 -385.681840      0.000005
# 1913  85264.444486 -308.585514  286.95   506.24 -304.605514      0.000004
# 1415  90054.234874 -305.715126    0.00  1063.97 -301.735126      0.000005
# 259   61041.555617 -296.094383    0.00  2633.67 -292.114383      0.000004
#
#       confidence  position_size
# 261     1.733479            1.0
# 262     1.972732            1.0
# 1913    1.697174            1.0
# 1415    2.000000            1.0
# 259     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 4.0, 'TRAIL_START_MULT': 0.5, 'TRAIL_STOP_MULT': 1.0, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $-638.98
# Trades: 1889
# Win Rate: 26.36%
# Expectancy: -0.34
# Profit Factor: 0.99
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: -0.10
# Long Trades: 1480 | Short Trades: 409
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1867 2025-05-22 13:00:00-04:00 2025-05-22 13:25:00-04:00  long    111353.82
# 1473 2025-01-20 07:40:00-05:00 2025-01-20 08:25:00-05:00  long    106816.01
# 1476 2025-01-21 16:20:00-05:00 2025-01-21 17:00:00-05:00  long    106249.11
# 1856 2025-05-21 13:50:00-04:00 2025-05-21 14:10:00-04:00  long    106232.34
# 1833 2025-05-12 02:55:00-04:00 2025-05-12 03:10:00-04:00  long    104997.91
#
#         exit_price        pnl     mfe     mae  gross_pnl  vol_adj_pred  \
# 1867  111910.58910  552.78910  594.64   40.51  556.76910      0.000004
# 1473  107350.09005  530.10005  643.89  164.90  534.08005      0.000004
# 1476  106780.35555  527.26555  565.26   29.11  531.24555      0.000004
# 1856  106763.50170  527.18170  858.57    0.00  531.16170      0.000005
# 1833  105522.89955  521.00955  762.09    0.00  524.98955      0.000005
#
#       confidence  position_size
# 1867    1.655708            1.0
# 1473    1.814035            1.0
# 1476    1.705929            1.0
# 1856    1.973684            1.0
# 1833    1.957519            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 227  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 228  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1678 2025-04-02 16:35:00-04:00 2025-04-02 17:05:00-04:00  long     85569.05
# 1233 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 225  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price         pnl     mfe      mae   gross_pnl  vol_adj_pred  \
# 227   60930.764240 -407.405760    0.00   876.78 -403.425760      0.000004
# 228   60191.718160 -389.661840    0.00  1377.40 -385.681840      0.000005
# 1678  85264.444486 -308.585514  286.95   506.24 -304.605514      0.000004
# 1233  90054.234874 -305.715126    0.00  1063.97 -301.735126      0.000005
# 225   61041.555617 -296.094383    0.00  2633.67 -292.114383      0.000004
#
#       confidence  position_size
# 227     1.733479            1.0
# 228     1.972732            1.0
# 1678    1.697174            1.0
# 1233    2.000000            1.0
# 225     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 4.0, 'TRAIL_START_MULT': 0.5, 'TRAIL_STOP_MULT': 0.3, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $2564.61
# Trades: 2242
# Win Rate: 40.68%
# Expectancy: 1.14
# Profit Factor: 1.03
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 0.46
# Long Trades: 1770 | Short Trades: 472
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1764 2025-01-20 08:15:00-05:00 2025-01-20 08:35:00-05:00  long    107027.19
# 2177 2025-05-12 02:55:00-04:00 2025-05-12 03:10:00-04:00  long    104997.91
# 1775 2025-01-24 09:30:00-05:00 2025-01-24 09:45:00-05:00  long    104936.44
# 2176 2025-05-11 20:55:00-04:00 2025-05-11 21:10:00-04:00  long    104551.28
# 1556 2024-12-05 09:20:00-05:00 2024-12-05 09:35:00-05:00  long    102301.28
#
#         exit_price        pnl      mfe  mae  gross_pnl  vol_adj_pred  \
# 1764  107562.32595  531.15595   872.81  0.0  535.13595      0.000004
# 2177  105522.89955  521.00955   762.09  0.0  524.98955      0.000005
# 1775  105461.12220  520.70220  1385.22  0.0  524.68220      0.000004
# 2176  105074.03640  518.77640   535.14  0.0  522.75640      0.000004
# 1556  102812.78640  507.52640   933.70  0.0  511.50640      0.000005
#
#       confidence  position_size
# 1764    1.682931            1.0
# 2177    1.957519            1.0
# 1775    1.647260            1.0
# 2176    1.697250            1.0
# 1556    2.000000            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 270  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 271  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1991 2025-04-02 16:35:00-04:00 2025-04-02 17:05:00-04:00  long     85569.05
# 1472 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 268  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price         pnl     mfe      mae   gross_pnl  vol_adj_pred  \
# 270   60930.764240 -407.405760    0.00   876.78 -403.425760      0.000004
# 271   60191.718160 -389.661840    0.00  1377.40 -385.681840      0.000005
# 1991  85264.444486 -308.585514  286.95   506.24 -304.605514      0.000004
# 1472  90054.234874 -305.715126    0.00  1063.97 -301.735126      0.000005
# 268   61041.555617 -296.094383    0.00  2633.67 -292.114383      0.000004
#
#       confidence  position_size
# 270     1.733479            1.0
# 271     1.972732            1.0
# 1991    1.697174            1.0
# 1472    2.000000            1.0
# 268     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 4.0, 'TRAIL_START_MULT': 1.0, 'TRAIL_STOP_MULT': 0.5, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $1051.99
# Trades: 2073
# Win Rate: 35.70%
# Expectancy: 0.51
# Profit Factor: 1.01
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 0.18
# Long Trades: 1633 | Short Trades: 440
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1624 2025-01-20 07:40:00-05:00 2025-01-20 08:25:00-05:00  long    106816.01
# 2037 2025-05-21 13:50:00-04:00 2025-05-21 14:10:00-04:00  long    106232.34
# 2013 2025-05-12 02:55:00-04:00 2025-05-12 03:10:00-04:00  long    104997.91
# 1635 2025-01-24 09:30:00-05:00 2025-01-24 09:45:00-05:00  long    104936.44
# 2012 2025-05-11 20:55:00-04:00 2025-05-11 21:10:00-04:00  long    104551.28
#
#         exit_price        pnl      mfe    mae  gross_pnl  vol_adj_pred  \
# 1624  107350.09005  530.10005   643.89  164.9  534.08005      0.000004
# 2037  106763.50170  527.18170   858.57    0.0  531.16170      0.000005
# 2013  105522.89955  521.00955   762.09    0.0  524.98955      0.000005
# 1635  105461.12220  520.70220  1385.22    0.0  524.68220      0.000004
# 2012  105074.03640  518.77640   535.14    0.0  522.75640      0.000004
#
#       confidence  position_size
# 1624    1.814035            1.0
# 2037    1.973684            1.0
# 2013    1.957519            1.0
# 1635    1.647260            1.0
# 2012    1.697250            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 251  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 252  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1841 2025-04-02 16:35:00-04:00 2025-04-02 17:05:00-04:00  long     85569.05
# 1359 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 249  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price         pnl     mfe      mae   gross_pnl  vol_adj_pred  \
# 251   60930.764240 -407.405760    0.00   876.78 -403.425760      0.000004
# 252   60191.718160 -389.661840    0.00  1377.40 -385.681840      0.000005
# 1841  85264.444486 -308.585514  286.95   506.24 -304.605514      0.000004
# 1359  90054.234874 -305.715126    0.00  1063.97 -301.735126      0.000005
# 249   61041.555617 -296.094383    0.00  2633.67 -292.114383      0.000004
#
#       confidence  position_size
# 251     1.733479            1.0
# 252     1.972732            1.0
# 1841    1.697174            1.0
# 1359    2.000000            1.0
# 249     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 4.0, 'TRAIL_START_MULT': 1.0, 'TRAIL_STOP_MULT': 1.0, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $39.50
# Trades: 1889
# Win Rate: 26.68%
# Expectancy: 0.02
# Profit Factor: 1.00
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 0.01
# Long Trades: 1487 | Short Trades: 402
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1866 2025-05-22 13:00:00-04:00 2025-05-22 13:25:00-04:00  long    111353.82
# 1468 2025-01-20 07:40:00-05:00 2025-01-20 08:25:00-05:00  long    106816.01
# 1855 2025-05-21 13:50:00-04:00 2025-05-21 14:10:00-04:00  long    106232.34
# 1471 2025-01-21 16:15:00-05:00 2025-01-21 16:35:00-05:00  long    105897.15
# 1832 2025-05-12 02:55:00-04:00 2025-05-12 03:10:00-04:00  long    104997.91
#
#         exit_price        pnl     mfe     mae  gross_pnl  vol_adj_pred  \
# 1866  111910.58910  552.78910  594.64   40.51  556.76910      0.000004
# 1468  107350.09005  530.10005  643.89  164.90  534.08005      0.000004
# 1855  106763.50170  527.18170  858.57    0.00  531.16170      0.000005
# 1471  106426.63575  525.50575  654.57    0.00  529.48575      0.000005
# 1832  105522.89955  521.00955  762.09    0.00  524.98955      0.000005
#
#       confidence  position_size
# 1866    1.655708            1.0
# 1468    1.814035            1.0
# 1855    1.973684            1.0
# 1471    2.000000            1.0
# 1832    1.957519            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 224  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 225  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1674 2025-04-02 16:35:00-04:00 2025-04-02 17:05:00-04:00  long     85569.05
# 1229 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 222  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price         pnl     mfe      mae   gross_pnl  vol_adj_pred  \
# 224   60930.764240 -407.405760    0.00   876.78 -403.425760      0.000004
# 225   60191.718160 -389.661840    0.00  1377.40 -385.681840      0.000005
# 1674  85264.444486 -308.585514  286.95   506.24 -304.605514      0.000004
# 1229  90054.234874 -305.715126    0.00  1063.97 -301.735126      0.000005
# 222   61041.555617 -296.094383    0.00  2633.67 -292.114383      0.000004
#
#       confidence  position_size
# 224     1.733479            1.0
# 225     1.972732            1.0
# 1674    1.697174            1.0
# 1229    2.000000            1.0
# 222     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 4.0, 'TRAIL_START_MULT': 1.0, 'TRAIL_STOP_MULT': 0.3, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $15441.78
# Trades: 2112
# Win Rate: 37.88%
# Expectancy: 7.31
# Profit Factor: 1.16
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 2.57
# Long Trades: 1667 | Short Trades: 445
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1656 2025-01-20 07:40:00-05:00 2025-01-20 08:25:00-05:00  long    106816.01
# 2075 2025-05-21 13:50:00-04:00 2025-05-21 14:10:00-04:00  long    106232.34
# 2051 2025-05-12 02:55:00-04:00 2025-05-12 03:10:00-04:00  long    104997.91
# 1667 2025-01-24 09:30:00-05:00 2025-01-24 09:45:00-05:00  long    104936.44
# 2050 2025-05-11 20:55:00-04:00 2025-05-11 21:10:00-04:00  long    104551.28
#
#         exit_price        pnl      mfe    mae  gross_pnl  vol_adj_pred  \
# 1656  107350.09005  530.10005   643.89  164.9  534.08005      0.000004
# 2075  106763.50170  527.18170   858.57    0.0  531.16170      0.000005
# 2051  105522.89955  521.00955   762.09    0.0  524.98955      0.000005
# 1667  105461.12220  520.70220  1385.22    0.0  524.68220      0.000004
# 2050  105074.03640  518.77640   535.14    0.0  522.75640      0.000004
#
#       confidence  position_size
# 1656    1.814035            1.0
# 2075    1.973684            1.0
# 2051    1.957519            1.0
# 1667    1.647260            1.0
# 2050    1.697250            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 255  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 256  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1874 2025-04-02 16:35:00-04:00 2025-04-02 17:05:00-04:00  long     85569.05
# 1378 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 253  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price         pnl     mfe      mae   gross_pnl  vol_adj_pred  \
# 255   60930.764240 -407.405760    0.00   876.78 -403.425760      0.000004
# 256   60191.718160 -389.661840    0.00  1377.40 -385.681840      0.000005
# 1874  85264.444486 -308.585514  286.95   506.24 -304.605514      0.000004
# 1378  90054.234874 -305.715126    0.00  1063.97 -301.735126      0.000005
# 253   61041.555617 -296.094383    0.00  2633.67 -292.114383      0.000004
#
#       confidence  position_size
# 255     1.733479            1.0
# 256     1.972732            1.0
# 1874    1.697174            1.0
# 1378    2.000000            1.0
# 253     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 4.0, 'TRAIL_START_MULT': 0.3, 'TRAIL_STOP_MULT': 0.5, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $-13201.42
# Trades: 2160
# Win Rate: 35.19%
# Expectancy: -6.11
# Profit Factor: 0.87
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: -2.42
# Long Trades: 1702 | Short Trades: 458
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1692 2025-01-20 08:05:00-05:00 2025-01-20 08:25:00-05:00  long    106839.76
# 2097 2025-05-12 02:55:00-04:00 2025-05-12 03:10:00-04:00  long    104997.91
# 1703 2025-01-24 09:30:00-05:00 2025-01-24 09:45:00-05:00  long    104936.44
# 2096 2025-05-11 20:55:00-04:00 2025-05-11 21:10:00-04:00  long    104551.28
# 2100 2025-05-13 10:10:00-04:00 2025-05-13 10:30:00-04:00  long    102889.54
#
#         exit_price        pnl      mfe   mae  gross_pnl  vol_adj_pred  \
# 1692  107373.95880  530.21880   620.14  3.09  534.19880      0.000004
# 2097  105522.89955  521.00955   762.09  0.00  524.98955      0.000005
# 1703  105461.12220  520.70220  1385.22  0.00  524.68220      0.000004
# 2096  105074.03640  518.77640   535.14  0.00  522.75640      0.000004
# 2100  103403.98770  510.46770   546.46  0.00  514.44770      0.000004
#
#       confidence  position_size
# 1692    1.764030            1.0
# 2097    1.957519            1.0
# 1703    1.647260            1.0
# 2096    1.697250            1.0
# 2100    1.730703            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 264  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 265  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1422 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 262  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
# 293  2024-03-08 11:00:00-05:00 2024-03-08 11:15:00-05:00  long     66946.86
#
#         exit_price         pnl  mfe      mae   gross_pnl  vol_adj_pred  \
# 264   60930.764240 -407.405760  0.0   876.78 -403.425760      0.000004
# 265   60191.718160 -389.661840  0.0  1377.40 -385.681840      0.000005
# 1422  90054.234874 -305.715126  0.0  1063.97 -301.735126      0.000005
# 262   61041.555617 -296.094383  0.0  2633.67 -292.114383      0.000004
# 293   66662.468156 -288.371844  0.0   864.20 -284.391844      0.000004
#
#       confidence  position_size
# 264     1.733479            1.0
# 265     1.972732            1.0
# 1422    2.000000            1.0
# 262     1.689292            1.0
# 293     1.743972            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 4.0, 'TRAIL_START_MULT': 0.3, 'TRAIL_STOP_MULT': 1.0, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $-638.98
# Trades: 1889
# Win Rate: 26.36%
# Expectancy: -0.34
# Profit Factor: 0.99
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: -0.10
# Long Trades: 1480 | Short Trades: 409
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1867 2025-05-22 13:00:00-04:00 2025-05-22 13:25:00-04:00  long    111353.82
# 1473 2025-01-20 07:40:00-05:00 2025-01-20 08:25:00-05:00  long    106816.01
# 1476 2025-01-21 16:20:00-05:00 2025-01-21 17:00:00-05:00  long    106249.11
# 1856 2025-05-21 13:50:00-04:00 2025-05-21 14:10:00-04:00  long    106232.34
# 1833 2025-05-12 02:55:00-04:00 2025-05-12 03:10:00-04:00  long    104997.91
#
#         exit_price        pnl     mfe     mae  gross_pnl  vol_adj_pred  \
# 1867  111910.58910  552.78910  594.64   40.51  556.76910      0.000004
# 1473  107350.09005  530.10005  643.89  164.90  534.08005      0.000004
# 1476  106780.35555  527.26555  565.26   29.11  531.24555      0.000004
# 1856  106763.50170  527.18170  858.57    0.00  531.16170      0.000005
# 1833  105522.89955  521.00955  762.09    0.00  524.98955      0.000005
#
#       confidence  position_size
# 1867    1.655708            1.0
# 1473    1.814035            1.0
# 1476    1.705929            1.0
# 1856    1.973684            1.0
# 1833    1.957519            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 227  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 228  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1678 2025-04-02 16:35:00-04:00 2025-04-02 17:05:00-04:00  long     85569.05
# 1233 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 225  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price         pnl     mfe      mae   gross_pnl  vol_adj_pred  \
# 227   60930.764240 -407.405760    0.00   876.78 -403.425760      0.000004
# 228   60191.718160 -389.661840    0.00  1377.40 -385.681840      0.000005
# 1678  85264.444486 -308.585514  286.95   506.24 -304.605514      0.000004
# 1233  90054.234874 -305.715126    0.00  1063.97 -301.735126      0.000005
# 225   61041.555617 -296.094383    0.00  2633.67 -292.114383      0.000004
#
#       confidence  position_size
# 227     1.733479            1.0
# 228     1.972732            1.0
# 1678    1.697174            1.0
# 1233    2.000000            1.0
# 225     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.5, 'TP_ATR_MULT': 4.0, 'TRAIL_START_MULT': 0.3, 'TRAIL_STOP_MULT': 0.3, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $1197.81
# Trades: 2269
# Win Rate: 39.53%
# Expectancy: 0.53
# Profit Factor: 1.01
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 0.22
# Long Trades: 1791 | Short Trades: 478
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1783 2025-01-20 08:15:00-05:00 2025-01-20 08:35:00-05:00  long    107027.19
# 2203 2025-05-12 02:55:00-04:00 2025-05-12 03:10:00-04:00  long    104997.91
# 1794 2025-01-24 09:30:00-05:00 2025-01-24 09:45:00-05:00  long    104936.44
# 2202 2025-05-11 20:55:00-04:00 2025-05-11 21:10:00-04:00  long    104551.28
# 1575 2024-12-05 09:20:00-05:00 2024-12-05 09:35:00-05:00  long    102301.28
#
#         exit_price        pnl      mfe  mae  gross_pnl  vol_adj_pred  \
# 1783  107562.32595  531.15595   872.81  0.0  535.13595      0.000004
# 2203  105522.89955  521.00955   762.09  0.0  524.98955      0.000005
# 1794  105461.12220  520.70220  1385.22  0.0  524.68220      0.000004
# 2202  105074.03640  518.77640   535.14  0.0  522.75640      0.000004
# 1575  102812.78640  507.52640   933.70  0.0  511.50640      0.000005
#
#       confidence  position_size
# 1783    1.682931            1.0
# 2203    1.957519            1.0
# 1794    1.647260            1.0
# 2202    1.697250            1.0
# 1575    2.000000            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 274  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 275  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1489 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 272  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
# 305  2024-03-08 11:00:00-05:00 2024-03-08 11:15:00-05:00  long     66946.86
#
# ...
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 273  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 274  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 2014 2025-04-02 16:35:00-04:00 2025-04-02 16:50:00-04:00  long     85569.05
# 1486 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 271  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price        pnl     mfe      mae  gross_pnl  vol_adj_pred  \
# 273   61253.504848 -84.665152    0.00   876.78 -80.685152      0.000004
# 274   60500.263632 -81.116368    0.00  1377.40 -77.136368      0.000005
# 2014  85508.128897 -64.901103  230.95   268.27 -60.921103      0.000004
# 1486  90295.622975 -64.327025    0.00  1063.97 -60.347025      0.000005
# 271   61275.247123 -62.402877    0.00  2633.67 -58.422877      0.000004
#
#       confidence  position_size
# 273     1.733479            1.0
# 274     1.972732            1.0
# 2014    1.697174            1.0
# 1486    2.000000            1.0
# 271     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.1, 'TP_ATR_MULT': 20.0, 'TRAIL_START_MULT': 1.0, 'TRAIL_STOP_MULT': 1.0, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $51996.57
# Trades: 2143
# Win Rate: 18.06%
# Expectancy: 24.26
# Profit Factor: 2.61
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 10.02
# Long Trades: 1687 | Short Trades: 456
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1674 2025-01-20 08:05:00-05:00 2025-01-20 08:25:00-05:00  long    106839.76
# 2105 2025-05-21 13:50:00-04:00 2025-05-21 14:10:00-04:00  long    106232.34
# 1677 2025-01-21 16:15:00-05:00 2025-01-21 16:35:00-05:00  long    105897.15
# 2079 2025-05-12 02:55:00-04:00 2025-05-12 03:10:00-04:00  long    104997.91
# 1685 2025-01-24 09:30:00-05:00 2025-01-24 09:45:00-05:00  long    104936.44
#
#         exit_price        pnl      mfe   mae  gross_pnl  vol_adj_pred  \
# 1674  107373.95880  530.21880   620.14  3.09  534.19880      0.000004
# 2105  106763.50170  527.18170   858.57  0.00  531.16170      0.000005
# 1677  106426.63575  525.50575   654.57  0.00  529.48575      0.000005
# 2079  105522.89955  521.00955   762.09  0.00  524.98955      0.000005
# 1685  105461.12220  520.70220  1385.22  0.00  524.68220      0.000004
#
#       confidence  position_size
# 1674    1.764030            1.0
# 2105    1.973684            1.0
# 1677    2.000000            1.0
# 2079    1.957519            1.0
# 1685    1.647260            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 258  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 259  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1904 2025-04-02 16:35:00-04:00 2025-04-02 16:50:00-04:00  long     85569.05
# 1404 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 256  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price        pnl     mfe      mae  gross_pnl  vol_adj_pred  \
# 258   61253.504848 -84.665152    0.00   876.78 -80.685152      0.000004
# 259   60500.263632 -81.116368    0.00  1377.40 -77.136368      0.000005
# 1904  85508.128897 -64.901103  230.95   268.27 -60.921103      0.000004
# 1404  90295.622975 -64.327025    0.00  1063.97 -60.347025      0.000005
# 256   61275.247123 -62.402877    0.00  2633.67 -58.422877      0.000004
#
#       confidence  position_size
# 258     1.733479            1.0
# 259     1.972732            1.0
# 1904    1.697174            1.0
# 1404    2.000000            1.0
# 256     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.1, 'TP_ATR_MULT': 20.0, 'TRAIL_START_MULT': 1.0, 'TRAIL_STOP_MULT': 0.3, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $61278.00
# Trades: 2298
# Win Rate: 26.68%
# Expectancy: 26.67
# Profit Factor: 2.98
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 13.35
# Long Trades: 1812 | Short Trades: 486
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1797 2025-01-20 08:05:00-05:00 2025-01-20 08:25:00-05:00  long    106839.76
# 2256 2025-05-21 13:50:00-04:00 2025-05-21 14:10:00-04:00  long    106232.34
# 2230 2025-05-12 02:55:00-04:00 2025-05-12 03:10:00-04:00  long    104997.91
# 1808 2025-01-24 09:30:00-05:00 2025-01-24 09:45:00-05:00  long    104936.44
# 2229 2025-05-11 20:55:00-04:00 2025-05-11 21:10:00-04:00  long    104551.28
#
#         exit_price        pnl      mfe   mae  gross_pnl  vol_adj_pred  \
# 1797  107373.95880  530.21880   620.14  3.09  534.19880      0.000004
# 2256  106763.50170  527.18170   858.57  0.00  531.16170      0.000005
# 2230  105522.89955  521.00955   762.09  0.00  524.98955      0.000005
# 1808  105461.12220  520.70220  1385.22  0.00  524.68220      0.000004
# 2229  105074.03640  518.77640   535.14  0.00  522.75640      0.000004
#
#       confidence  position_size
# 1797    1.764030            1.0
# 2256    1.973684            1.0
# 2230    1.957519            1.0
# 1808    1.647260            1.0
# 2229    1.697250            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 275  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 276  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 2036 2025-04-02 16:35:00-04:00 2025-04-02 16:50:00-04:00  long     85569.05
# 1499 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 273  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price        pnl     mfe      mae  gross_pnl  vol_adj_pred  \
# 275   61253.504848 -84.665152    0.00   876.78 -80.685152      0.000004
# 276   60500.263632 -81.116368    0.00  1377.40 -77.136368      0.000005
# 2036  85508.128897 -64.901103  230.95   268.27 -60.921103      0.000004
# 1499  90295.622975 -64.327025    0.00  1063.97 -60.347025      0.000005
# 273   61275.247123 -62.402877    0.00  2633.67 -58.422877      0.000004
#
#       confidence  position_size
# 275     1.733479            1.0
# 276     1.972732            1.0
# 2036    1.697174            1.0
# 1499    2.000000            1.0
# 273     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.1, 'TP_ATR_MULT': 20.0, 'TRAIL_START_MULT': 0.3, 'TRAIL_STOP_MULT': 0.5, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $48426.67
# Trades: 2297
# Win Rate: 25.56%
# Expectancy: 21.08
# Profit Factor: 2.55
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 11.02
# Long Trades: 1807 | Short Trades: 490
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1793 2025-01-20 08:05:00-05:00 2025-01-20 08:25:00-05:00  long    106839.76
# 2229 2025-05-12 02:55:00-04:00 2025-05-12 03:10:00-04:00  long    104997.91
# 1804 2025-01-24 09:30:00-05:00 2025-01-24 09:45:00-05:00  long    104936.44
# 2228 2025-05-11 20:55:00-04:00 2025-05-11 21:10:00-04:00  long    104551.28
# 2232 2025-05-13 10:10:00-04:00 2025-05-13 10:30:00-04:00  long    102889.54
#
#         exit_price        pnl      mfe   mae  gross_pnl  vol_adj_pred  \
# 1793  107373.95880  530.21880   620.14  3.09  534.19880      0.000004
# 2229  105522.89955  521.00955   762.09  0.00  524.98955      0.000005
# 1804  105461.12220  520.70220  1385.22  0.00  524.68220      0.000004
# 2228  105074.03640  518.77640   535.14  0.00  522.75640      0.000004
# 2232  103403.98770  510.46770   546.46  0.00  514.44770      0.000004
#
#       confidence  position_size
# 1793    1.764030            1.0
# 2229    1.957519            1.0
# 1804    1.647260            1.0
# 2228    1.697250            1.0
# 2232    1.730703            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 276  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 277  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 2034 2025-04-02 16:35:00-04:00 2025-04-02 16:50:00-04:00  long     85569.05
# 1502 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 274  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price        pnl     mfe      mae  gross_pnl  vol_adj_pred  \
# 276   61253.504848 -84.665152    0.00   876.78 -80.685152      0.000004
# 277   60500.263632 -81.116368    0.00  1377.40 -77.136368      0.000005
# 2034  85508.128897 -64.901103  230.95   268.27 -60.921103      0.000004
# 1502  90295.622975 -64.327025    0.00  1063.97 -60.347025      0.000005
# 274   61275.247123 -62.402877    0.00  2633.67 -58.422877      0.000004
#
#       confidence  position_size
# 276     1.733479            1.0
# 277     1.972732            1.0
# 2034    1.697174            1.0
# 1502    2.000000            1.0
# 274     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.1, 'TP_ATR_MULT': 20.0, 'TRAIL_START_MULT': 0.3, 'TRAIL_STOP_MULT': 1.0, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $51954.67
# Trades: 2143
# Win Rate: 18.06%
# Expectancy: 24.24
# Profit Factor: 2.61
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 10.01
# Long Trades: 1687 | Short Trades: 456
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1674 2025-01-20 08:05:00-05:00 2025-01-20 08:25:00-05:00  long    106839.76
# 1677 2025-01-21 16:20:00-05:00 2025-01-21 17:00:00-05:00  long    106249.11
# 2105 2025-05-21 13:50:00-04:00 2025-05-21 14:10:00-04:00  long    106232.34
# 2079 2025-05-12 02:55:00-04:00 2025-05-12 03:10:00-04:00  long    104997.91
# 1685 2025-01-24 09:30:00-05:00 2025-01-24 09:45:00-05:00  long    104936.44
#
#         exit_price        pnl      mfe    mae  gross_pnl  vol_adj_pred  \
# 1674  107373.95880  530.21880   620.14   3.09  534.19880      0.000004
# 1677  106780.35555  527.26555   565.26  29.11  531.24555      0.000004
# 2105  106763.50170  527.18170   858.57   0.00  531.16170      0.000005
# 2079  105522.89955  521.00955   762.09   0.00  524.98955      0.000005
# 1685  105461.12220  520.70220  1385.22   0.00  524.68220      0.000004
#
#       confidence  position_size
# 1674    1.764030            1.0
# 1677    1.705929            1.0
# 2105    1.973684            1.0
# 2079    1.957519            1.0
# 1685    1.647260            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 258  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 259  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 1904 2025-04-02 16:35:00-04:00 2025-04-02 16:50:00-04:00  long     85569.05
# 1404 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 256  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price        pnl     mfe      mae  gross_pnl  vol_adj_pred  \
# 258   61253.504848 -84.665152    0.00   876.78 -80.685152      0.000004
# 259   60500.263632 -81.116368    0.00  1377.40 -77.136368      0.000005
# 1904  85508.128897 -64.901103  230.95   268.27 -60.921103      0.000004
# 1404  90295.622975 -64.327025    0.00  1063.97 -60.347025      0.000005
# 256   61275.247123 -62.402877    0.00  2633.67 -58.422877      0.000004
#
#       confidence  position_size
# 258     1.733479            1.0
# 259     1.972732            1.0
# 1904    1.697174            1.0
# 1404    2.000000            1.0
# 256     1.689292            1.0
#
#
# 🔍 Evaluating with params: {'SL_ATR_MULT': 0.1, 'TP_ATR_MULT': 20.0, 'TRAIL_START_MULT': 0.3, 'TRAIL_STOP_MULT': 0.3, 'TICK_VALUE': 20}
#
# ✅ LOOKAHEAD=12 | Threshold=4e-06
# PnL: $57183.12
# Trades: 2368
# Win Rate: 29.43%
# Expectancy: 24.15
# Profit Factor: 2.88
# Average Confidence Win: 0.0000046
# Average Confidence Loss: 0.0000046
# Sharpe Ratio: 13.06
# Long Trades: 1863 | Short Trades: 505
# Avoid Hits:
#
# 🔢 Top 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 1853 2025-01-20 08:15:00-05:00 2025-01-20 08:35:00-05:00  long    107027.19
# 2299 2025-05-12 02:55:00-04:00 2025-05-12 03:10:00-04:00  long    104997.91
# 1864 2025-01-24 09:30:00-05:00 2025-01-24 09:45:00-05:00  long    104936.44
# 2298 2025-05-11 20:55:00-04:00 2025-05-11 21:10:00-04:00  long    104551.28
# 1631 2024-12-05 09:20:00-05:00 2024-12-05 09:35:00-05:00  long    102301.28
#
#         exit_price        pnl      mfe  mae  gross_pnl  vol_adj_pred  \
# 1853  107562.32595  531.15595   872.81  0.0  535.13595      0.000004
# 2299  105522.89955  521.00955   762.09  0.0  524.98955      0.000005
# 1864  105461.12220  520.70220  1385.22  0.0  524.68220      0.000004
# 2298  105074.03640  518.77640   535.14  0.0  522.75640      0.000004
# 1631  102812.78640  507.52640   933.70  0.0  511.50640      0.000005
#
#       confidence  position_size
# 1853    1.682931            1.0
# 2299    1.957519            1.0
# 1864    1.647260            1.0
# 2298    1.697250            1.0
# 1631    2.000000            1.0
#
# 🔻 Bottom 5 PnL trades:
#                     entry_time                 exit_time  side  entry_price  \
# 285  2024-02-28 12:55:00-05:00 2024-02-28 13:10:00-05:00  long     61334.19
# 286  2024-02-28 13:10:00-05:00 2024-02-28 13:25:00-05:00  long     60577.40
# 2097 2025-04-02 16:35:00-04:00 2025-04-02 16:50:00-04:00  long     85569.05
# 1544 2024-11-13 14:50:00-05:00 2024-11-13 15:05:00-05:00  long     90355.97
# 283  2024-02-28 12:20:00-05:00 2024-02-28 12:35:00-05:00  long     61333.67
#
#         exit_price        pnl     mfe      mae  gross_pnl  vol_adj_pred  \
# 285   61253.504848 -84.665152    0.00   876.78 -80.685152      0.000004
# 286   60500.263632 -81.116368    0.00  1377.40 -77.136368      0.000005
# 2097  85508.128897 -64.901103  230.95   268.27 -60.921103      0.000004
# 1544  90295.622975 -64.327025    0.00  1063.97 -60.347025      0.000005
# 283   61275.247123 -62.402877    0.00  2633.67 -58.422877      0.000004
#
#       confidence  position_size
# 285     1.733479            1.0
# 286     1.972732            1.0
# 2097    1.697174            1.0
# 1544    2.000000            1.0
# 283     1.689292            1.0
#
# 🏁 Top 10 Configurations Across All Lookaheads:
#               pnl     sharpe  expectancy  profit_factor  win_rate  trades  \
# 167  61896.732280  13.594697   26.935045       2.997153  0.267624    2298
# 212  61277.995319  13.354341   26.665794       2.975152  0.266754    2298
# 185  61277.995319  13.354341   26.665794       2.975152  0.266754    2298
# 194  61277.995319  13.354341   26.665794       2.975152  0.266754    2298
# 203  61277.995319  13.354341   26.665794       2.975152  0.266754    2298
# 176  61074.883235  13.333412   26.577408       2.968605  0.266754    2298
# 164  56653.051143  13.253395   23.995363       2.866425  0.295637    2361
# 200  57546.840710  13.161722   24.373927       2.895023  0.295214    2361
# 209  57546.840710  13.161722   24.373927       2.895023  0.295214    2361
# 182  57546.840710  13.161722   24.373927       2.895023  0.295214    2361
#
#      avg_confidence_win  avg_confidence_loss
# 167            0.000005             0.000005
# 212            0.000005             0.000005
# 185            0.000005             0.000005
# 194            0.000005             0.000005
# 203            0.000005             0.000005
# 176            0.000005             0.000005
# 164            0.000005             0.000005
# 200            0.000005             0.000005
# 209            0.000005             0.000005
# 182            0.000005             0.000005

# %% [markdown]
# # Visualize

# %%
best_result = None

def compute_max_consecutive_loss(df):
    """
    Calculates the worst cumulative loss (drawdown) from any starting point.
    """
    pnl_series = df['pnl'].values
    max_loss = 0.0
    start_idx = 0
    end_idx = 0

    for i in range(len(pnl_series)):
        cumulative = 0.0
        for j in range(i, len(pnl_series)):
            cumulative += pnl_series[j]
            if cumulative < max_loss:
                max_loss = cumulative
                start_idx = i
                end_idx = j

    return max_loss, df['entry_time'].iloc[start_idx], df['entry_time'].iloc[end_idx]


for r in all_results:
    df = r['results'].copy()
    df = df.sort_values(by='entry_time')
    df['cumulative_pnl'] = df['pnl'].cumsum()

    if (
        df['cumulative_pnl'].iloc[-1] > 0 and
        r['sharpe'] > 1 and
        r['trades'] > 1 and
        r['win_rate'] > 0.001 and
        r['profit_factor'] > 0.01 and
        r['expectancy'] > 0.01 and
        r['pnl'] > 100
    ):
        if best_result is None or r['sharpe'] > best_result['sharpe']:
            best_result = r.copy()
            best_result['cumulative_pnl'] = df['cumulative_pnl']
            best_result['entry_time'] = df['entry_time']

            # === Calculate max drawdown (largest PnL loss from peak)
            cumulative = df['cumulative_pnl']
            rolling_max = cumulative.cummax()
            drawdowns = cumulative - rolling_max
            max_drawdown = drawdowns.min()  # Most negative drop
            max_drawdown_start = rolling_max[drawdowns.idxmin()]
            best_result['max_drawdown'] = max_drawdown

# === Plot the best one ===
# === After determining best_result
if best_result:
    df = best_result['results'].copy()
    df = df.sort_values(by='entry_time')
    df['cumulative_pnl'] = df['pnl'].cumsum()

    max_loss, loss_start, loss_end = compute_max_consecutive_loss(df)

    # === Plot
    plt.figure(figsize=(12, 4))
    plt.plot(df['entry_time'], df['cumulative_pnl'], label='Cumulative PnL', color='green')
    plt.axvspan(loss_start, loss_end, color='red', alpha=0.2, label='Max Loss Window')
    plt.title(f"Top Sharpe Strategy | Max Consecutive Loss: {max_loss:.2f} | Cumulative PnL: {best_result['pnl']:.2f}")
    plt.xlabel("Datetime")
    plt.ylabel("Cumulative PnL")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

    print(f"💣 Max Consecutive PnL Loss: {max_loss:.2f}")
    print(f"📆 Period: {loss_start} → {loss_end}")
    best_result['results'].to_csv("best_strategy_results.csv", index=False)
    print("✅ Saved best_strategy_results.csv")
else:
    print("❌ No strategy met the conditions.")
# Out:
# 💣 Max Consecutive PnL Loss: -523.99
# 📆 Period: 2025-02-27 05:20:00-05:00 → 2025-03-06 02:05:00-05:00
# ✅ Saved best_strategy_results.csv
